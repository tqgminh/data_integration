# %%
import fuzzymatcher
import pandas as pd

# %%
cps_df = pd.read_csv('clean_data/cellphones.csv')
tgdd_df = pd.read_csv('clean_data/tgdd.csv')
tiki_df = pd.read_csv('clean_data/tiki.csv')
vt_df = pd.read_csv('clean_data/viettel.csv')
ddv_df = pd.read_csv('clean_data/didongviet.csv')
dmx_df = pd.read_csv('clean_data/dienmayxanh.csv')

cps_df['src'] = 'CellphoneS'
tgdd_df['src'] = 'Thế giới di động'
tiki_df['src'] = 'Tiki'
vt_df['src'] = 'Viettel'
ddv_df['src'] = 'Di động Việt'
dmx_df['src'] = "Điện máy xanh"

# %%
print(len(cps_df) + len(tgdd_df) + len(tiki_df) + len(vt_df) + len(ddv_df) + len(dmx_df))
# Out:
# 812

# %%
def get_brand(s):
    s = s.lower()
    if 'iphone' in s:
        return 'apple'
    elif 'samsung' in s:
        return 'samsung'
    elif 'xiaomi' in s:
        return 'xiaomi'
    elif 'oppo' in s:
        return 'oppo'
    else:
        return 'other'

# %%
cps_df['thuong_hieu'] = cps_df['ten'].apply(get_brand)
tgdd_df['thuong_hieu'] = tgdd_df['ten'].apply(get_brand)
tiki_df['thuong_hieu'] = tiki_df['ten'].apply(get_brand)
vt_df['thuong_hieu'] = vt_df['ten'].apply(get_brand)
ddv_df['thuong_hieu'] = ddv_df['ten'].apply(get_brand)
dmx_df['thuong_hieu'] = dmx_df['ten'].apply(get_brand)

# %%
apple_cps_df = cps_df[cps_df['thuong_hieu'] == 'apple']
ss_cps_df = cps_df[cps_df['thuong_hieu'] == 'samsung']
xiaomi_cps_df = cps_df[cps_df['thuong_hieu'] == 'xiaomi']
oppo_cps_df = cps_df[cps_df['thuong_hieu'] == 'oppo']
other_cps_df = cps_df[cps_df['thuong_hieu'] == 'other']

# %%
apple_tgdd_df = tgdd_df[tgdd_df['thuong_hieu'] == 'apple']
ss_tgdd_df = tgdd_df[tgdd_df['thuong_hieu'] == 'samsung']
xiaomi_tgdd_df = tgdd_df[tgdd_df['thuong_hieu'] == 'xiaomi']
oppo_tgdd_df = tgdd_df[tgdd_df['thuong_hieu'] == 'oppo']
other_tgdd_df = tgdd_df[tgdd_df['thuong_hieu'] == 'other']

# %%
apple_tiki_df = tiki_df[tiki_df['thuong_hieu'] == 'apple']
ss_tiki_df = tiki_df[tiki_df['thuong_hieu'] == 'samsung']
xiaomi_tiki_df = tiki_df[tiki_df['thuong_hieu'] == 'xiaomi']
oppo_tiki_df = tiki_df[tiki_df['thuong_hieu'] == 'oppo']
other_tiki_df = tiki_df[tiki_df['thuong_hieu'] == 'other']

# %%
apple_vt_df = vt_df[vt_df['thuong_hieu'] == 'apple']
ss_vt_df = vt_df[vt_df['thuong_hieu'] == 'samsung']
xiaomi_vt_df = vt_df[vt_df['thuong_hieu'] == 'xiaomi']
oppo_vt_df = vt_df[vt_df['thuong_hieu'] == 'oppo']
other_vt_df = vt_df[vt_df['thuong_hieu'] == 'other']

# %%
apple_ddv_df = ddv_df[ddv_df['thuong_hieu'] == 'apple']
ss_ddv_df = ddv_df[ddv_df['thuong_hieu'] == 'samsung']
xiaomi_ddv_df = ddv_df[ddv_df['thuong_hieu'] == 'xiaomi']
oppo_ddv_df = ddv_df[ddv_df['thuong_hieu'] == 'oppo']
other_ddv_df = ddv_df[ddv_df['thuong_hieu'] == 'other']

# %%
apple_dmx_df = dmx_df[dmx_df['thuong_hieu'] == 'apple']
ss_dmx_df = dmx_df[dmx_df['thuong_hieu'] == 'samsung']
xiaomi_dmx_df = dmx_df[dmx_df['thuong_hieu'] == 'xiaomi']
oppo_dmx_df = dmx_df[dmx_df['thuong_hieu'] == 'oppo']
other_dmx_df = dmx_df[dmx_df['thuong_hieu'] == 'other']

# %%
left_on = ["ten", "gia",  "ram", "bo_nho_trong", "kich_thuoc_man_hinh"]
right_on = ["ten", "gia",  "ram", "bo_nho_trong", "kich_thuoc_man_hinh"]

# %% [markdown]
# # Matching data Apple

# %% [markdown]
# ## TGDD

# %%
apple_df = apple_tgdd_df
len(apple_df)
# Out:
# 4

# %% [markdown]
# ## CellphoneS

# %%
apple_matcher = fuzzymatcher.link_table(apple_df, apple_cps_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
apple_matcher = apple_matcher[apple_matcher['match_score'] > 0.2]
apple_matcher
# Out:
#    __id_left  __id_right  match_score  match_rank             ten_left  \
# 0          2          76     0.239175           1  iPhone 12 Pro 256GB
# 2          8          27     0.273974           1  iPhone 12 mini 64GB
#
#              ten_right  gia_left  gia_right  ram_left  ram_right  \
# 0  iPhone 12 Pro 256GB  26290000   26000000       6.0        6.0
# 2  iPhone 12 mini 64GB  18990000   15000000       4.0        4.0
#
#    bo_nho_trong_left  bo_nho_trong_right  kich_thuoc_man_hinh_left  \
# 0              256.0               256.0                       6.1
# 2               64.0                64.0                       5.4
#
#    kich_thuoc_man_hinh_right
# 0                        6.1
# 2                        5.4

# %%
values = apple_matcher['__id_right'].unique().tolist()
apple_cps_df = apple_cps_df.query("id not in @values")

apple_df = pd.concat([apple_df, apple_cps_df])
apple_df = apple_df.reset_index(drop=True)
apple_df['id'] = apple_df.index
print(len(apple_df))
# Out:
# 42

# %% [markdown]
# ## Viettel

# %%
apple_matcher = fuzzymatcher.link_table(apple_df, apple_vt_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
apple_matcher = apple_matcher[apple_matcher['match_score'] > 0.2]
apple_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank                 ten_left  \
# 14           5           3     0.361549           1  iPhone 13 Pro Max 128GB
# 55          14           4     0.377752           1  iPhone 13 Pro Max 256GB
# 74          17          21     0.382566           1     iPhone 13 mini 128GB
# 94          21          17     0.283054           1      iPhone 13 Pro 256GB
# 112         23           4     0.242267           1  iPhone 13 Pro Max 512GB
# 113         24          10     0.331866           1    iPhone 13 Pro Max 1TB
# 166         34          95     0.272665           1     iPhone 13 mini 256GB
# 192         39          93     0.237168           1        iPhone 13 Pro 1TB
#
#                    ten_right  gia_left  gia_right  ram_left  ram_right  \
# 14   iPhone 13 Pro Max 128GB  29690000   29490000       6.0        6.0
# 55   iPhone 13 Pro Max 256GB  32190000   31990000       6.0        6.0
# ...

# %%
values = apple_matcher['__id_right'].unique().tolist()
apple_vt_df = apple_vt_df.query("id not in @values")

apple_df = pd.concat([apple_df, apple_vt_df])
apple_df = apple_df.reset_index(drop=True)
apple_df['id'] = apple_df.index
print(len(apple_df))
# Out:
# 52

# %% [markdown]
# ## Tiki

# %%
apple_matcher = fuzzymatcher.link_table(apple_df, apple_tiki_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
apple_matcher = apple_matcher[apple_matcher['match_score'] > 0.1]
apple_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank               ten_left  \
# 13           4         111     0.169973           1         iPhone 11 64GB
# 33          11           9     0.112382           1    iPhone 13 Pro 128GB
# 51          17         232     0.122416           1   iPhone 13 mini 128GB
# 124         42           9     0.112382           1    iPhone 13 Pro 128GB
# 125         43         111     0.169973           1         iPhone 11 64GB
# 141         50         115     0.127539           1  iPhone SE (2022) 64GB
#
#                 ten_right  gia_left  gia_right  ram_left  ram_right  \
# 13         iPhone 11 64GB  11690000   21990000       4.0        4.0
# 33    Apple iPhone 13 Pro  27190000   26850000       6.0        6.0
# 51   Apple iPhone 13 Mini  18990000   17990000       4.0        4.0
# 124   Apple iPhone 13 Pro  27490000   26850000       6.0        6.0
# 125        iPhone 11 64GB  12290000   21990000       4.0        4.0
# ...

# %%
values = apple_matcher['__id_right'].unique().tolist()
apple_tiki_df = apple_tiki_df.query("id not in @values")

apple_df = pd.concat([apple_df, apple_tiki_df])
apple_df = apple_df.reset_index(drop=True)
apple_df['id'] = apple_df.index
print(len(apple_df))
# Out:
# 52

# %% [markdown]
# ## Didongviet

# %%
apple_matcher = fuzzymatcher.link_table(apple_df, apple_ddv_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
apple_matcher = apple_matcher[apple_matcher['match_score'] > 0.12]
apple_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 2            1          10     0.188951           1
# 46           4          11     0.184786           1
# 47           5           4     0.273126           1
# 48           5          13     0.209511           2
# 79           7           4     0.270350           1
# 83           9          12     0.152978           1
# 85          11           1     0.181373           1
# 87          12         105     0.214300           1
# 88          12          18     0.179102           2
# 92          14           5     0.228526           1
# 93          14          14     0.154877           2
# 128         18           0     0.141446           1
# 132         20          16     0.221577           1
# 133         20          19     0.186378           2
# 134         21           2     0.198683           1
# 166         23           5     0.185158           1
# 168         24           7     0.284865           1
# ...

# %%
values = apple_matcher['__id_right'].unique().tolist()
apple_ddv_df = apple_ddv_df.query("id not in @values")

apple_df = pd.concat([apple_df, apple_ddv_df])
apple_df = apple_df.reset_index(drop=True)
apple_df['id'] = apple_df.index
print(len(apple_df))
# Out:
# 56

# %% [markdown]
# ## Điện máy xanh

# %%
apple_matcher = fuzzymatcher.link_table(apple_df, apple_dmx_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
apple_matcher = apple_matcher[apple_matcher['match_score'] > 0.1]
apple_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 4            1          13     0.143199           1
# 5            2          15     0.211312           1
# 6            3          18     0.265506           1
# 28          10          16     0.116383           1
# 79          25          16     0.110091           1
# 84          27          15     0.130159           1
# 107         35          16     0.104221           1
# 139         46          13     0.133165           1
#
#                             ten_left                        ten_right  \
# 4                     iPhone 12 64GB                   iPhone 12 64GB
# 5                iPhone 12 mini 64GB              iPhone 12 mini 64GB
# 6    iPhone SE 64GB (2020) (Hộp mới)  iPhone SE 64GB (2020) (Hop moi)
# 28                    iPhone SE 2022            iPhone SE 64GB (2022)
# 79              iPhone SE 2022 128GB            iPhone SE 64GB (2022)
# 84              iPhone 12 mini 128GB              iPhone 12 mini 64GB
# ...

# %%
values = apple_matcher['__id_right'].unique().tolist()
apple_dmx_df = apple_dmx_df.query("id not in @values")

apple_df = pd.concat([apple_df, apple_dmx_df])
apple_df = apple_df.reset_index(drop=True)
apple_df['id'] = apple_df.index
print(len(apple_df))
# Out:
# 56

# %% [markdown]
# # Matching data Samsung

# %% [markdown]
# ## TGDD

# %%
ss_df = ss_tgdd_df
len(ss_df)
# Out:
# 10

# %% [markdown]
# ## CellphoneS

# %%
ss_matcher = fuzzymatcher.link_table(ss_df, ss_cps_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
ss_matcher = ss_matcher[ss_matcher['match_score'] > 0.25]
ss_matcher
# Out:
#     __id_left  __id_right  match_score  match_rank  \
# 15          5          24     0.258573           1
# 16          9          26     0.574687           1
# 30         33          40     0.370668           1
#
#                                 ten_left  \
# 15       Samsung Galaxy Z Flip3 5G 128GB
# 16  Samsung Galaxy S21 FE 5G (6GB/128GB)
# 30                Samsung Galaxy A03 3GB
#
#                                  ten_right  gia_left  gia_right  ram_left  \
# 15               Samsung Galaxy Z Flip3 5G  21990000   20790000       8.0
# 16  Samsung Galaxy S21 FE 5G (6GB - 128GB)  15990000   13300000       6.0
# 30         Samsung Galaxy A03 (3GB - 32GB)   2990000    2850000       3.0
#
#     ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 15        8.0              128.0               128.0
# 16        6.0              128.0               128.0
# 30        3.0               32.0                32.0
#
#     kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# ...

# %%
values = ss_matcher['__id_right'].unique().tolist()
ss_cps_df = ss_cps_df.query("id not in @values")

ss_df = pd.concat([ss_df, ss_cps_df])
ss_df = ss_df.reset_index(drop=True)
ss_df['id'] = ss_df.index
print(len(ss_df))
# Out:
# 47

# %% [markdown]
# ## Viettel

# %%
ss_matcher = fuzzymatcher.link_table(ss_df, ss_vt_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
ss_matcher = ss_matcher[ss_matcher['match_score'] > 0.2]
ss_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 0            0          36     0.512265           1
# 1            1          61     0.252257           1
# 16           4           5     0.342454           1
# 17           5         107     0.529003           1
# 57           9          15     0.207254           1
# 58          10          70     0.297387           1
# 89          12          61     0.287224           1
# 90          13          60     0.254900           1
# 130         19          67     0.274317           1
# 139         21          59     0.255191           1
# 222         26           9     0.219085           1
# 223         27          36     0.237130           1
# 225         28          71     0.397125           1
# 226         29          37     0.366492           1
# 301         34          14     0.218857           1
# 332         36           0     0.242189           1
# 426         42         111     0.298899           1
# ...

# %%
values = ss_matcher['__id_right'].unique().tolist()
ss_vt_df = ss_vt_df.query("id not in @values")

ss_df = pd.concat([ss_df, ss_vt_df])
ss_df = ss_df.reset_index(drop=True)
ss_df['id'] = ss_df.index
print(len(ss_df))
# Out:
# 62

# %% [markdown]
# ## Tiki

# %%
ss_matcher = fuzzymatcher.link_table(ss_df, ss_tiki_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
ss_matcher = ss_matcher[ss_matcher['match_score'] > 0.2]
ss_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank  \
# 64            1         113     0.424582           1
# 65            2         133     0.209010           1
# 68            3         133     0.332309           1
# 139           6         192     0.235563           1
# 140           7          52     0.231398           1
# 141           7         169     0.231398           2
# 153           9         237     0.323529           1
# 154           9         242     0.317659           2
# 155          10          49     0.301394           1
# 224          13         130     0.232775           1
# 392          19          70     0.359775           1
# 393          19          89     0.359775           2
# 394          19         122     0.359775           3
# 413          22         132     0.212939           1
# 431          23          65     0.385411           1
# 523          26         102     0.229398           1
# 524          26         144     0.229398           2
# ...

# %%
values = ss_matcher['__id_right'].unique().tolist()
ss_tiki_df = ss_tiki_df.query("id not in @values")

ss_df = pd.concat([ss_df, ss_tiki_df])
ss_df = ss_df.reset_index(drop=True)
ss_df['id'] = ss_df.index
print(len(ss_df))
# Out:
# 114

# %% [markdown]
# ## Didongviet

# %%
ss_matcher = fuzzymatcher.link_table(ss_df, ss_ddv_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
ss_matcher = ss_matcher[ss_matcher['match_score'] > 0.25]
ss_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank  \
# 0             0          39     0.526455           1
# 1             1          29     0.400894           1
# 2             1         111     0.358786           2
# 8             3          25     0.321358           1
# 9             4          36     0.444182           1
# 18            6         101     0.273301           1
# 22            9          46     0.379071           1
# 219          19          34     0.401076           1
# 376          26         119     0.272575           1
# 385          29          37     0.339334           1
# 386          29         125     0.307261           2
# 564          36          30     0.399519           1
# 565          36         110     0.357411           2
# 608          38          28     0.330755           1
# 609          38         112     0.288647           2
# 942          51          38     0.568563           1
# 971          56          31     0.281829           1
# ...

# %%
values = ss_matcher['__id_right'].unique().tolist()
ss_ddv_df = ss_ddv_df.query("id not in @values")

ss_df = pd.concat([ss_df, ss_ddv_df])
ss_df = ss_df.reset_index(drop=True)
ss_df['id'] = ss_df.index
print(len(ss_df))
# Out:
# 128

# %% [markdown]
# ## Điện máy xanh

# %%
ss_matcher = fuzzymatcher.link_table(ss_df, ss_dmx_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
ss_matcher = ss_matcher[ss_matcher['match_score'] > 0.21]
ss_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 0            0           8     0.505814           1
# 1            1           0     0.383659           1
# 2            2           9     0.246248           1
# 5            3          10     0.298124           1
# 6            4          14     0.409598           1
# 7            5          17     0.501307           1
# 8            6          23     0.230019           1
# 9            7          27     0.230019           1
# 13           9           4     0.336004           1
# 144         27           8     0.220022           1
# 317         51           8     0.312056           1
# 318         52          23     0.233790           1
# 328         54          27     0.233790           1
# 329         55           0     0.229951           1
# 371         63           4     0.320100           1
# 420         74           4     0.320100           1
# 589        104           4     0.330134           1
# ...

# %%
values = ss_matcher['__id_right'].unique().tolist()
ss_dmx_df = ss_dmx_df.query("id not in @values")

ss_df = pd.concat([ss_df, ss_dmx_df])
ss_df = ss_df.reset_index(drop=True)
ss_df['id'] = ss_df.index
print(len(ss_df))
# Out:
# 128

# %% [markdown]
# # Matching data Xiaomi

# %% [markdown]
# ## TGDD

# %%
xiaomi_df = xiaomi_tgdd_df
len(xiaomi_df)
# Out:
# 9

# %% [markdown]
# ## CellphoneS

# %%
xiaomi_matcher = fuzzymatcher.link_table(xiaomi_df, xiaomi_cps_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
xiaomi_matcher = xiaomi_matcher[xiaomi_matcher['match_score'] > 0.2]
xiaomi_matcher
# Out:
#     __id_left  __id_right  match_score  match_rank  \
# 40         25         161     0.203326           1
# 46         34         136     0.382221           1
#
#                            ten_left                   ten_right  gia_left  \
# 40  Xiaomi Redmi Note 11 (4GB/64GB)    Xiaomi Redmi Note 10 4GB   4190000
# 46       Xiaomi Redmi 9C (3GB/64GB)  Xiaomi Redmi 9C 3GB - 64GB   2990000
#
#     gia_right  ram_left  ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 40    4250000       4.0        4.0               64.0                64.0
# 46    2890000       3.0        3.0               64.0                64.0
#
#     kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 40                      6.43                       6.43
# 46                      6.53                       6.53

# %%
values = xiaomi_matcher['__id_right'].unique().tolist()
xiaomi_cps_df = xiaomi_cps_df.query("id not in @values")

xiaomi_df = pd.concat([xiaomi_df, xiaomi_cps_df])
xiaomi_df = xiaomi_df.reset_index(drop=True)
xiaomi_df['id'] = xiaomi_df.index
print(len(xiaomi_df))
# Out:
# 40

# %% [markdown]
# ## Viettel

# %%
xiaomi_matcher = fuzzymatcher.link_table(xiaomi_df, xiaomi_vt_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
xiaomi_matcher = xiaomi_matcher[xiaomi_matcher['match_score'] > 0.2]
xiaomi_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 0            0         103     0.245943           1
# 21           2          26     0.307850           1
# 22           2          24     0.268239           2
# 30           4          56     0.210973           1
# 38           6          51     0.406145           1
# 42           8          69     0.388536           1
# 62          11          76     0.248810           1
# 63          12          80     0.224165           1
# 64          13         105     0.210493           1
# 66          14          41     0.386831           1
# 67          15          79     0.211492           1
# 146         20          49     0.363776           1
# 187         23          77     0.290241           1
# 376         35          49     0.210519           1
#
#                                  ten_left                         ten_right  \
# 0                               Xiaomi 12                      Xiaomi 12 5G
# ...

# %%
values = xiaomi_matcher['__id_right'].unique().tolist()
xiaomi_vt_df = xiaomi_vt_df.query("id not in @values")

xiaomi_df = pd.concat([xiaomi_df, xiaomi_vt_df])
xiaomi_df = xiaomi_df.reset_index(drop=True)
xiaomi_df['id'] = xiaomi_df.index
print(len(xiaomi_df))
# Out:
# 47

# %% [markdown]
# ## Tiki

# %%
xiaomi_matcher = fuzzymatcher.link_table(xiaomi_df, xiaomi_tiki_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
xiaomi_matcher = xiaomi_matcher[xiaomi_matcher['match_score'] > 0.2]
xiaomi_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 43           1          86     0.307685           1
# 44           1          72     0.226723           2
# 51           2          16     0.224866           1
# 52           2          17     0.224866           2
# 76           6          40     0.493508           1
# 97           8          43     0.380500           1
# 98           8         101     0.380500           2
# 99           9          71     0.279597           1
# 103         12          97     0.276506           1
# 212         17          53     0.276289           1
# 213         17          97     0.276289           2
# 300         20         105     0.464025           1
# 301         20          71     0.398524           2
# 365         23         110     0.397514           1
# 498         29         110     0.235835           1
# 674         35         105     0.305344           1
# 675         35          71     0.239843           2
# ...

# %%
values = xiaomi_matcher['__id_right'].unique().tolist()
xiaomi_tiki_df = xiaomi_tiki_df.query("id not in @values")

xiaomi_df = pd.concat([xiaomi_df, xiaomi_tiki_df])
xiaomi_df = xiaomi_df.reset_index(drop=True)
xiaomi_df['id'] = xiaomi_df.index
print(len(xiaomi_df))
# Out:
# 75

# %% [markdown]
# ## Didongviet

# %%
xiaomi_matcher = fuzzymatcher.link_table(xiaomi_df, xiaomi_ddv_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
xiaomi_matcher = xiaomi_matcher[xiaomi_matcher['match_score'] > 0.2]
xiaomi_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 20           2         100     0.237422           1
# 27           6         120     0.386457           1
# 40          10          70     0.285687           1
# 86          20          51     0.364232           1
# 107         23         100     0.244817           1
# 275         44         121     0.200888           1
# 293         49         121     0.287983           1
# 294         50         121     0.287983           1
# 295         51         120     0.257289           1
# 297         52         120     0.273193           1
# 309         54         115     0.388917           1
# 313         56         121     0.287983           1
# 320         60         100     0.533503           1
# 324         62         115     0.508051           1
# 326         64         120     0.257289           1
# 338         66         115     0.388917           1
# 339         67         100     0.533503           1
# ...

# %%
values = xiaomi_matcher['__id_right'].unique().tolist()
xiaomi_ddv_df = xiaomi_ddv_df.query("id not in @values")

xiaomi_df = pd.concat([xiaomi_df, xiaomi_ddv_df])
xiaomi_df = xiaomi_df.reset_index(drop=True)
xiaomi_df['id'] = xiaomi_df.index
print(len(xiaomi_df))
# Out:
# 78

# %% [markdown]
# ## Điện máy xanh

# %%
xiaomi_matcher = fuzzymatcher.link_table(xiaomi_df, xiaomi_dmx_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
xiaomi_matcher = xiaomi_matcher[xiaomi_matcher['match_score'] > 0.2]
xiaomi_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 1            1           3     0.317619           1
# 2            2           5     0.312748           1
# 3            3           6     0.434861           1
# 4            4          22     0.468602           1
# 14           6          25     0.329471           1
# 15           7          30     0.272838           1
# 16           8          31     0.458796           1
# 26          10          26     0.236496           1
# 295         51          25     0.329471           1
# 296         52          25     0.345375           1
# 358         64          25     0.329471           1
# 359         65           3     0.257457           1
#
#                                ten_left                        ten_right  \
# 1                   Xiaomi 11T 5G 128GB              Xiaomi 11T 5G 128GB
# 2              Xiaomi Redmi Note 11 Pro         Xiaomi Redmi Note 11 Pro
# ...

# %%
values = xiaomi_matcher['__id_right'].unique().tolist()
xiaomi_dmx_df = xiaomi_dmx_df.query("id not in @values")

xiaomi_df = pd.concat([xiaomi_df, xiaomi_dmx_df])
xiaomi_df = xiaomi_df.reset_index(drop=True)
xiaomi_df['id'] = xiaomi_df.index
print(len(xiaomi_df))
# Out:
# 79

# %% [markdown]
# ## Matching data Oppo

# %% [markdown]
# ## TGDD

# %%
oppo_df = oppo_tgdd_df
len(oppo_df)
# Out:
# 2

# %% [markdown]
# ## CellphoneS

# %%
oppo_matcher = fuzzymatcher.link_table(oppo_df, oppo_cps_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
oppo_matcher = oppo_matcher[oppo_matcher['match_score'] > 0.2]
oppo_matcher
# Out:
#    __id_left  __id_right  match_score  match_rank         ten_left  \
# 0         11          25     0.202764           1    OPPO Reno6 5G
# 2         12           5     0.379585           1  OPPO Reno7 Z 5G
#
#            ten_right  gia_left  gia_right  ram_left  ram_right  \
# 0      OPPO Reno6 5G  10990000   10290000       8.0        8.0
# 2  OPPO Reno7 Z (5G)  10490000   10490000       8.0        8.0
#
#    bo_nho_trong_left  bo_nho_trong_right  kich_thuoc_man_hinh_left  \
# 0              128.0               128.0                      6.43
# 2              128.0               128.0                      6.43
#
#    kich_thuoc_man_hinh_right
# 0                       6.43
# 2                       6.43

# %%
values = oppo_matcher['__id_right'].unique().tolist()
oppo_cps_df = oppo_cps_df.query("id not in @values")

oppo_df = pd.concat([oppo_df, oppo_cps_df])
oppo_df = oppo_df.reset_index(drop=True)
oppo_df['id'] = oppo_df.index
print(len(oppo_df))
# Out:
# 20

# %% [markdown]
# ## Viettel

# %%
oppo_matcher = fuzzymatcher.link_table(oppo_df, oppo_vt_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
oppo_matcher = oppo_matcher[oppo_matcher['match_score'] > 0.25]
oppo_matcher
# Out:
#    __id_left  __id_right  match_score  match_rank         ten_left  \
# 1          1          30     0.251972           1  OPPO Reno7 Z 5G
#
#          ten_right  gia_left  gia_right  ram_left  ram_right  \
# 1  OPPO Reno7 Z 5G  10490000    9990000       8.0        8.0
#
#    bo_nho_trong_left  bo_nho_trong_right  kich_thuoc_man_hinh_left  \
# 1              128.0               128.0                      6.43
#
#    kich_thuoc_man_hinh_right
# 1                       6.43

# %%
values = oppo_matcher['__id_right'].unique().tolist()
oppo_vt_df = oppo_vt_df.query("id not in @values")

oppo_df = pd.concat([oppo_df, oppo_vt_df])
oppo_df = oppo_df.reset_index(drop=True)
oppo_df['id'] = oppo_df.index
print(len(oppo_df))
# Out:
# 29

# %% [markdown]
# ## Tiki

# %%
oppo_matcher = fuzzymatcher.link_table(oppo_df, oppo_tiki_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
oppo_matcher = oppo_matcher[oppo_matcher['match_score'] > 0.2]
oppo_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank         ten_left  \
# 1            1         172     0.249246           1  OPPO Reno7 Z 5G
# 2            2         225     0.249246           1  OPPO Reno6 Z 5G
# 48           9         218     0.215903           1        OPPO A16K
# 235         19          41     0.220247           1        OPPO A15s
# 250         22         234     0.219922           1         OPPO A76
# 268         27         146     0.215903           1        OPPO A16K
#
#                        ten_right  gia_left  gia_right  ram_left  ram_right  \
# 1    OPPO RENO7 Z 5G (8GB/128GB)  10490000    9990000       8.0        8.0
# 2    Oppo Reno6 Z 5G (8GB/128GB)   7390000    8289000       8.0        8.0
# 48          OPPO A16K (3GB/32GB)   3190000    3190000       3.0        3.0
# 235          Oppo A15s (4GB/64G)   3790000    3790000       4.0        4.0
# 250           Oppo A76 6GB/128GB   5990000    5990000       6.0        6.0
# ...

# %%
values = oppo_matcher['__id_right'].unique().tolist()
oppo_tiki_df = oppo_tiki_df.query("id not in @values")

oppo_df = pd.concat([oppo_df, oppo_tiki_df])
oppo_df = oppo_df.reset_index(drop=True)
oppo_df['id'] = oppo_df.index
print(len(oppo_df))
# Out:
# 57

# %% [markdown]
# ## Didongviet

# %%
oppo_matcher = fuzzymatcher.link_table(oppo_df, oppo_ddv_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
oppo_matcher = oppo_matcher[oppo_matcher['match_score'] > 0.2]
oppo_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 166         29         116     0.209849           1
# 170         31          48     0.255741           1
# 192         36          50     0.219361           1
# 196         38          43     0.349878           1
# 197         39         131     0.225043           1
# 198         39         126     0.207206           2
# 213         42          50     0.203457           1
# 214         43          40     0.365782           1
# 215         44         116     0.291605           1
# 226         47          40     0.365782           1
# 239         49          43     0.444380           1
# 240         50          50     0.333931           1
# 241         51          43     0.365782           1
# 242         52          43     0.365782           1
#
#                       ten_left                    ten_right  gia_left  \
# 166        Oppo A76 (6GB/128G)         OPPO A76 (6GB|128GB)   5490000
# ...

# %%
values = oppo_matcher['__id_right'].unique().tolist()
oppo_ddv_df = oppo_ddv_df.query("id not in @values")

oppo_df = pd.concat([oppo_df, oppo_ddv_df])
oppo_df = oppo_df.reset_index(drop=True)
oppo_df['id'] = oppo_df.index
print(len(oppo_df))
# Out:
# 62

# %% [markdown]
# ## Điện máy xanh

# %%
oppo_matcher = fuzzymatcher.link_table(oppo_df, oppo_dmx_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
oppo_matcher = oppo_matcher[oppo_matcher['match_score'] > 0.1]
oppo_matcher
# Out:
# Empty DataFrame
# Columns: [__id_left, __id_right, match_score, match_rank, ten_left, ten_right, gia_left, gia_right, ram_left, ram_right, bo_nho_trong_left, bo_nho_trong_right, kich_thuoc_man_hinh_left, kich_thuoc_man_hinh_right]
# Index: []

# %%
values = oppo_matcher['__id_right'].unique().tolist()
oppo_dmx_df = oppo_dmx_df.query("id not in @values")

oppo_df = pd.concat([oppo_df, oppo_dmx_df])
oppo_df = oppo_df.reset_index(drop=True)
oppo_df['id'] = oppo_df.index
print(len(oppo_df))
# Out:
# 63

# %% [markdown]
# # Matching data other

# %% [markdown]
# ## TGDD

# %%
other_df = other_tgdd_df
len(other_df)
# Out:
# 11

# %% [markdown]
# ## CellphoneS

# %%
other_matcher = fuzzymatcher.link_table(other_df, other_cps_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
other_matcher = other_matcher[other_matcher['match_score'] > 0.2]
other_matcher
# Out:
#     __id_left  __id_right  match_score  match_rank              ten_left  \
# 0          14         159     0.227171           1             Vivo V23e
# 1          14          99     0.226992           2             Vivo V23e
# 16         22         188     0.262736           1      Realme C25Y 64GB
# 19         24          79     0.256458           1       Realme C35 64GB
# 23         26          96     0.268599           1              Vivo Y21
# 28         28          77     0.273864           1             Vivo Y15s
# 32         32          55     0.307608           1     Realme C11 (2021)
# 33         35         109     0.227810           1  Nokia 105 Single SIM
#
#                 ten_right  gia_left  gia_right  ram_left  ram_right  \
# 0             Vivo V21 5G   8490000    8500000       8.0        8.0
# 1               Vivo V23e   8490000    7490000       8.0        8.0
# 16   Realme C25Y 4GB 64GB   4690000    3790000       4.0        4.0
# ...

# %%
values = other_matcher['__id_right'].unique().tolist()
other_cps_df = other_cps_df.query("id not in @values")

other_df = pd.concat([other_df, other_cps_df])
other_df = other_df.reset_index(drop=True)
other_df['id'] = other_df.index
print(len(other_df))
# Out:
# 111

# %% [markdown]
# ## Viettel

# %%
other_matcher = fuzzymatcher.link_table(other_df, other_vt_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
other_matcher = other_matcher[other_matcher['match_score'] > 0.2]
other_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank  \
# 0             0         100     0.263582           1
# 44            4          91     0.295975           1
# 45            5          78     0.261942           1
# 86            7          31     0.243910           1
# 733          28         106     0.346681           1
# 975          36          27     0.322156           1
# 977          38         113     0.277836           1
# 1146         44          32     0.243514           1
# 1227         47          43     0.364589           1
# 1311         51         114     0.267801           1
# 1313         52          88     0.211499           1
# 1397         57         101     0.233830           1
# 1642         67          90     0.321748           1
# 1643         68          68     0.220627           1
# 1885         76          28     0.205342           1
# 2073         82          82     0.402105           1
# 2157         86          82     0.200701           1
# ...

# %%
values = other_matcher['__id_right'].unique().tolist()
other_vt_df = other_vt_df.query("id not in @values")

other_df = pd.concat([other_df, other_vt_df])
other_df = other_df.reset_index(drop=True)
other_df['id'] = other_df.index
print(len(other_df))
# Out:
# 134

# %% [markdown]
# ## Tiki

# %%
other_matcher = fuzzymatcher.link_table(other_df, other_tiki_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
other_matcher = other_matcher[other_matcher['match_score'] > 0.2]
other_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank  \
# 77            4         236     0.252560           1
# 84            8         126     0.267929           1
# 480          16           4     0.321334           1
# 482          17         134     0.499078           1
# 989          28         112     0.483858           1
# 1127         32         121     0.322674           1
# 1381         36          68     0.475319           1
# 1382         36         183     0.421425           2
# 1662         41         106     0.255967           1
# 1663         41         213     0.255967           2
# 1746         43          47     0.487475           1
# 1747         43         164     0.487475           2
# 2198         52         181     0.275966           1
# 2551         62         199     0.284727           1
# 2628         67          63     0.472795           1
# 2915         72         201     0.223738           1
# 3399         82         108     0.351641           1
# ...

# %%
values = other_matcher['__id_right'].unique().tolist()
other_tiki_df = other_tiki_df.query("id not in @values")

other_df = pd.concat([other_df, other_tiki_df])
other_df = other_df.reset_index(drop=True)
other_df['id'] = other_df.index
print(len(other_df))
# Out:
# 198

# %% [markdown]
# ## Didongviet

# %%
other_matcher = fuzzymatcher.link_table(other_df, other_ddv_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
other_matcher = other_matcher[other_matcher['match_score'] > 0.2]
other_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank  \
# 230           5          60     0.200616           1
# 960          24          69     0.348018           1
# 1846         46          68     0.321672           1
# 1883         47          59     0.555015           1
# 2022         51          67     0.299409           1
# 2208         57          68     0.204426           1
# 3936        100          58     0.619095           1
# 5450        137          69     0.225146           1
# 5543        140          69     0.209242           1
# 6033        153          61     0.220109           1
# 6266        160          60     0.309309           1
# 6360        163          61     0.245708           1
# 6545        168          69     0.484354           1
# 6638        171          60     0.230212           1
# 6732        174          55     0.232596           1
# 6964        181          68     0.304789           1
# 7011        183          60     0.230212           1
# ...

# %%
values = other_matcher['__id_right'].unique().tolist()
other_ddv_df = other_ddv_df.query("id not in @values")

other_df = pd.concat([other_df, other_ddv_df])
other_df = other_df.reset_index(drop=True)
other_df['id'] = other_df.index
print(len(other_df))
# Out:
# 236

# %% [markdown]
# ## Điện máy xanh

# %%
other_matcher = fuzzymatcher.link_table(other_df, other_dmx_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
other_matcher = other_matcher[other_matcher['match_score'] > 0.11]
other_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank                 ten_left  \
# 0             0          20     0.189912           1                Vivo V23e
# 1             1          19     0.400935           1          Realme 9 Pro 5G
# 3             3          28     0.200390           1         Realme C25Y 64GB
# 4             4           2     0.314200           1          Realme C35 64GB
# 16            6          29     0.323623           1         Realme C21-Y 3GB
# 17            7           7     0.194159           1                Vivo Y15s
# 19            9          32     0.219016           1        Realme C11 (2021)
# 185          25          19     0.123391           1             Realme 9 Pro
# 209          29          21     0.119392           1                 Realme 8
# 276          36          33     0.136727           1  Nokia C21 Plus 3GB 64GB
# 380          47          24     0.225394           1  Vivo Y21S (4GB - 128GB)
# ...

# %%
values = other_matcher['__id_right'].unique().tolist()
other_dmx_df = other_dmx_df.query("id not in @values")

other_df = pd.concat([other_df, other_dmx_df])
other_df = other_df.reset_index(drop=True)
other_df['id'] = other_df.index
print(len(other_df))
# Out:
# 237

# %% [markdown]
# ## Merge all

# %%
df = pd.concat([apple_df, ss_df, xiaomi_df, oppo_df, other_df])
df = df.reset_index(drop=True)
print(len(df))
# Out:
# 563

# %%
df = df.drop_duplicates(subset=['ten'])
print(len(df))
# Out:
# 502

# %%
del df['Unnamed: 0.1']
del df['Unnamed: 0']

# %%
df.head()
# Out:
#                                ten       gia cong_nghe_man_hinh  \
# 0              iPhone 12 Pro 256GB  26290000               OLED
# 1                   iPhone 12 64GB  19990000               OLED
# 2              iPhone 12 mini 64GB  18990000               OLED
# 3  iPhone SE 64GB (2020) (Hộp mới)   9490000            IPS LCD
# 4                   iPhone 11 64GB  11690000            IPS LCD
#
#                        cpu  ram  bo_nho_trong                  sim       pin  \
# 0  Apple A14 Bionic 6 nhân  6.0         256.0  1 Nano SIM & 1 eSIM  2815 mAh
# 1  Apple A14 Bionic 6 nhân  4.0          64.0  1 Nano SIM & 1 eSIM  2815 mAh
# 2  Apple A14 Bionic 6 nhân  4.0          64.0  1 Nano SIM & 1 eSIM  2227 mAh
# 3  Apple A13 Bionic 6 nhân  3.0          64.0  1 Nano SIM & 1 eSIM  1821 mAh
# 4               A13 Bionic  4.0          64.0      Nano-SIM + eSIM  3110 mAh
#
#    kich_thuoc_man_hinh  id               src thuong_hieu
# 0                  6.1   0  Thế giới di động       apple
# ...

# %%
df.to_csv('clean_data/final_data.csv', index=False)
df.to_json('clean_data/final_data.json', orient="records")
