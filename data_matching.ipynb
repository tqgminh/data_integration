# %%
import fuzzymatcher
import pandas as pd

# %%
cps_df = pd.read_csv('clean_data/cellphones.csv')
tgdd_df = pd.read_csv('clean_data/tgdd.csv')
tiki_df = pd.read_csv('clean_data/tiki.csv')
vt_df = pd.read_csv('clean_data/viettel.csv')
ddv_df = pd.read_csv('clean_data/didongviet.csv')

cps_df['id'] = cps_df.index
tgdd_df['id'] = tgdd_df.index
tiki_df['id'] = tiki_df.index
vt_df['id'] = vt_df.index
ddv_df['id'] = ddv_df.index

cps_df['src'] = 'CellphoneS'
tgdd_df['src'] = 'Thế giới di động'
tiki_df['src'] = 'Tiki'
vt_df['src'] = 'Viettel'
ddv_df['src'] = 'Di động Việt'

# %%
print(len(cps_df) + len(tgdd_df) + len(tiki_df) + len(vt_df) + len(ddv_df))
# Out:
# 778

# %%
def get_brand(s):
    s = s.lower()
    if 'iphone' in s:
        return 'apple'
    elif 'samsung' in s:
        return 'samsung'
    elif 'xiaomi' in s:
        return 'xiaomi'
    elif 'oppo' in s:
        return 'oppo'
    else:
        return 'other'

# %%
cps_df['thuong_hieu'] = cps_df['ten'].apply(get_brand)
tgdd_df['thuong_hieu'] = tgdd_df['ten'].apply(get_brand)
tiki_df['thuong_hieu'] = tiki_df['ten'].apply(get_brand)
vt_df['thuong_hieu'] = vt_df['ten'].apply(get_brand)
ddv_df['thuong_hieu'] = ddv_df['ten'].apply(get_brand)

# %%
apple_cps_df = cps_df[cps_df['thuong_hieu'] == 'apple']
ss_cps_df = cps_df[cps_df['thuong_hieu'] == 'samsung']
xiaomi_cps_df = cps_df[cps_df['thuong_hieu'] == 'xiaomi']
oppo_cps_df = cps_df[cps_df['thuong_hieu'] == 'oppo']
other_cps_df = cps_df[cps_df['thuong_hieu'] == 'other']

# %%
apple_tgdd_df = tgdd_df[tgdd_df['thuong_hieu'] == 'apple']
ss_tgdd_df = tgdd_df[tgdd_df['thuong_hieu'] == 'samsung']
xiaomi_tgdd_df = tgdd_df[tgdd_df['thuong_hieu'] == 'xiaomi']
oppo_tgdd_df = tgdd_df[tgdd_df['thuong_hieu'] == 'oppo']
other_tgdd_df = tgdd_df[tgdd_df['thuong_hieu'] == 'other']

# %%
apple_tiki_df = tiki_df[tiki_df['thuong_hieu'] == 'apple']
ss_tiki_df = tiki_df[tiki_df['thuong_hieu'] == 'samsung']
xiaomi_tiki_df = tiki_df[tiki_df['thuong_hieu'] == 'xiaomi']
oppo_tiki_df = tiki_df[tiki_df['thuong_hieu'] == 'oppo']
other_tiki_df = tiki_df[tiki_df['thuong_hieu'] == 'other']

# %%
apple_vt_df = vt_df[vt_df['thuong_hieu'] == 'apple']
ss_vt_df = vt_df[vt_df['thuong_hieu'] == 'samsung']
xiaomi_vt_df = vt_df[vt_df['thuong_hieu'] == 'xiaomi']
oppo_vt_df = vt_df[vt_df['thuong_hieu'] == 'oppo']
other_vt_df = vt_df[vt_df['thuong_hieu'] == 'other']

# %%
apple_ddv_df = ddv_df[ddv_df['thuong_hieu'] == 'apple']
ss_ddv_df = ddv_df[ddv_df['thuong_hieu'] == 'samsung']
xiaomi_ddv_df = ddv_df[ddv_df['thuong_hieu'] == 'xiaomi']
oppo_ddv_df = ddv_df[ddv_df['thuong_hieu'] == 'oppo']
other_ddv_df = ddv_df[ddv_df['thuong_hieu'] == 'other']

# %%
left_on = ["ten", "gia",  "ram", "bo_nho_trong", "kich_thuoc_man_hinh"]
right_on = ["ten", "gia",  "ram", "bo_nho_trong", "kich_thuoc_man_hinh"]

# %% [markdown]
# # Matching data Apple

# %% [markdown]
# ## TGDD

# %%
apple_df = apple_tgdd_df
len(apple_df)
# Out:
# 4

# %% [markdown]
# ## CellphoneS

# %%
apple_matcher = fuzzymatcher.link_table(apple_df, apple_cps_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
apple_matcher = apple_matcher[apple_matcher['match_score'] > 0.2]
apple_matcher
# Out:
#    __id_left  __id_right  match_score  match_rank             ten_left  \
# 0          2          76     0.220153           1  iPhone 12 Pro 256GB
# 2          8          27     0.254952           1  iPhone 12 mini 64GB
#
#              ten_right  gia_left  gia_right  ram_left  ram_right  \
# 0  iPhone 12 Pro 256GB  26290000   26000000         6          6
# 2  iPhone 12 mini 64GB  18990000   15000000         4          4
#
#    bo_nho_trong_left  bo_nho_trong_right  kich_thuoc_man_hinh_left  \
# 0              256.0               256.0                       6.1
# 2               64.0                64.0                       5.4
#
#    kich_thuoc_man_hinh_right
# 0                        6.1
# 2                        5.4

# %%
values = apple_matcher['__id_right'].unique().tolist()
apple_cps_df = apple_cps_df.query("id not in @values")

apple_df = pd.concat([apple_df, apple_cps_df])
apple_df = apple_df.reset_index(drop=True)
apple_df['id'] = apple_df.index
print(len(apple_df))
# Out:
# 42

# %% [markdown]
# ## Viettel

# %%
apple_matcher = fuzzymatcher.link_table(apple_df, apple_vt_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
apple_matcher = apple_matcher[apple_matcher['match_score'] > 0.2]
apple_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank                 ten_left  \
# 14           5           3     0.341481           1  iPhone 13 Pro Max 128GB
# 55          14           4     0.357683           1  iPhone 13 Pro Max 256GB
# 74          17          21     0.362497           1     iPhone 13 mini 128GB
# 94          21          17     0.262985           1      iPhone 13 Pro 256GB
# 112         23           4     0.222198           1  iPhone 13 Pro Max 512GB
# 113         24          10     0.311797           1    iPhone 13 Pro Max 1TB
# 173         34          95     0.252596           1     iPhone 13 mini 256GB
# 199         39          93     0.217099           1        iPhone 13 Pro 1TB
#
#                    ten_right  gia_left  gia_right  ram_left  ram_right  \
# 14   iPhone 13 Pro Max 128GB  29690000   29490000         6          6
# 55   iPhone 13 Pro Max 256GB  32190000   31990000         6          6
# 74      iPhone 13 mini 128GB  18990000   18990000         4          4
# 94       iPhone 13 Pro 256GB  29950000   29690000         6          6
# 112  iPhone 13 Pro Max 256GB  37500000   31990000         6          6
# 113    iPhone 13 Pro Max 1TB  44000000   41790000         6          6
# 173     iPhone 13 mini 256GB  19990000   21490000         4          4
# 199        iPhone 13 Pro 1TB  40000000   39490000         6          6
#
#      bo_nho_trong_left  bo_nho_trong_right  kich_thuoc_man_hinh_left  \
# 14               128.0               128.0                       6.7
# 55               256.0               256.0                       6.7
# 74               128.0               128.0                       5.4
# 94               256.0               256.0                       6.1
# 112              256.0               256.0                       6.7
# 113             1024.0              1024.0                       6.7
# 173              256.0               256.0                       5.4
# 199             1024.0              1024.0                       6.1
#
#      kich_thuoc_man_hinh_right
# 14                         6.7
# 55                         6.7
# 74                         5.4
# 94                         6.1
# 112                        6.7
# 113                        6.7
# 173                        5.4
# 199                        6.1

# %%
values = apple_matcher['__id_right'].unique().tolist()
apple_vt_df = apple_vt_df.query("id not in @values")

apple_df = pd.concat([apple_df, apple_vt_df])
apple_df = apple_df.reset_index(drop=True)
apple_df['id'] = apple_df.index
print(len(apple_df))
# Out:
# 52

# %% [markdown]
# ## Tiki

# %%
apple_matcher = fuzzymatcher.link_table(apple_df, apple_tiki_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
apple_matcher = apple_matcher[apple_matcher['match_score'] > 0.2]
apple_matcher
# Out:
# Empty DataFrame
# Columns: [__id_left, __id_right, match_score, match_rank, ten_left, ten_right, gia_left, gia_right, ram_left, ram_right, bo_nho_trong_left, bo_nho_trong_right, kich_thuoc_man_hinh_left, kich_thuoc_man_hinh_right]
# Index: []

# %%
values = apple_matcher['__id_right'].unique().tolist()
apple_tiki_df = apple_tiki_df.query("id not in @values")

apple_df = pd.concat([apple_df, apple_tiki_df])
apple_df = apple_df.reset_index(drop=True)
apple_df['id'] = apple_df.index
print(len(apple_df))
# Out:
# 56

# %% [markdown]
# ## Didongviet

# %%
apple_matcher = fuzzymatcher.link_table(apple_df, apple_ddv_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
apple_matcher = apple_matcher[apple_matcher['match_score'] > 0.2]
apple_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 47           5           4     0.258057           1
# 79           7           4     0.256353           1
# 87          12         105     0.213228           1
# 92          14           5     0.213456           1
# 132         20          16     0.220504           1
# 168         24           7     0.269796           1
# 259         36           8     0.254190           1
# 260         37          24     0.297133           1
# 261         37          22     0.223483           2
# 292         39          17     0.239954           1
#
#                       ten_left                     ten_right  gia_left  \
# 47     iPhone 13 Pro Max 128GB       iPhone 13 Pro Max 128GB  29690000
# 79     iPhone 12 Pro Max 128GB       iPhone 13 Pro Max 128GB  27000000
# 87   iPhone 13 128GB - Xanh la       iPhone 13 128GB Xanh la  22000000
# 92     iPhone 13 Pro Max 256GB       iPhone 13 Pro Max 256GB  32190000
# 132  iPhone 13 256GB - Xanh la       iPhone 13 256GB Xanh La  23950000
# 168      iPhone 13 Pro Max 1TB         iPhone 13 Pro Max 1TB  44000000
# 259        iPhone 12 Pro 512GB           iPhone 12 Pro 512GB  27500000
# 260       iPhone 13 mini 512GB          iPhone 13 mini 512GB  23000000
# 261       iPhone 13 mini 512GB  iPhone 13 mini 512GB Xanh la  23000000
# 292          iPhone 13 Pro 1TB             iPhone 13 Pro 1TB  40000000
#
#      gia_right  ram_left  ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 47    26990000         6        6.0              128.0               128.0
# 79    26990000         6        6.0              128.0               128.0
# 87    19790000         0        4.0              128.0               128.0
# 92    29990000         6        0.0              256.0               256.0
# 132   22990000         0        4.0              256.0               256.0
# 168   41990000         6        0.0             1024.0              1024.0
# 259   27400000         6        0.0              512.0               512.0
# 260   21990000         4        4.0              512.0               512.0
# 261   21990000         4        4.0              512.0               512.0
# 292   37990000         6        6.0             1024.0              1024.0
#
#      kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 47                        6.7                        6.7
# 79                        6.7                        6.7
# 87                        6.1                        6.1
# 92                        6.7                        6.7
# 132                       6.1                        6.1
# 168                       6.7                        6.7
# 259                       6.1                        6.1
# 260                       5.4                        5.4
# 261                       5.4                        5.4
# 292                       6.1                        6.1

# %%
values = apple_matcher['__id_right'].unique().tolist()
apple_ddv_df = apple_ddv_df.query("id not in @values")

apple_df = pd.concat([apple_df, apple_ddv_df])
apple_df = apple_df.reset_index(drop=True)
apple_df['id'] = apple_df.index
print(len(apple_df))
# Out:
# 77

# %% [markdown]
# # Matching data Samsung

# %% [markdown]
# ## TGDD

# %%
ss_df = ss_tgdd_df
len(ss_df)
# Out:
# 10

# %% [markdown]
# ## CellphoneS

# %%
ss_matcher = fuzzymatcher.link_table(ss_df, ss_cps_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
ss_matcher = ss_matcher[ss_matcher['match_score'] > 0.2]
ss_matcher
# Out:
#     __id_left  __id_right  match_score  match_rank  \
# 0           0         112     0.218353           1
# 3           1          39     0.232312           1
# 15          5          24     0.240209           1
# 16          9          26     0.556323           1
# 30         33          40     0.352305           1
#
#                                 ten_left  \
# 0        Samsung Galaxy Z Fold3 5G 256GB
# 3      Samsung Galaxy S22 Ultra 5G 128GB
# 15       Samsung Galaxy Z Flip3 5G 128GB
# 16  Samsung Galaxy S21 FE 5G (6GB/128GB)
# 30                Samsung Galaxy A03 3GB
#
#                                  ten_right  gia_left  gia_right  ram_left  \
# 0                Samsung Galaxy Z Fold2 5G  35990000   23000000        12
# 3              Samsung Galaxy S21 Ultra 5G  30990000   20390000         8
# 15               Samsung Galaxy Z Flip3 5G  21990000   20790000         8
# 16  Samsung Galaxy S21 FE 5G (6GB - 128GB)  15990000   13300000         6
# 30         Samsung Galaxy A03 (3GB - 32GB)   2990000    2850000         3
#
#     ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 0          12              256.0               256.0
# 3          12              128.0               128.0
# 15          8              128.0               128.0
# 16          6              128.0               128.0
# 30          3               32.0                32.0
#
#     kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 0                       13.8                      13.83
# 3                        6.8                       6.80
# 15                       8.6                       6.70
# 16                       6.4                       6.40
# 30                       6.5                       6.50

# %%
values = ss_matcher['__id_right'].unique().tolist()
ss_cps_df = ss_cps_df.query("id not in @values")

ss_df = pd.concat([ss_df, ss_cps_df])
ss_df = ss_df.reset_index(drop=True)
ss_df['id'] = ss_df.index
print(len(ss_df))
# Out:
# 45

# %% [markdown]
# ## Viettel

# %%
ss_matcher = fuzzymatcher.link_table(ss_df, ss_vt_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
ss_matcher = ss_matcher[ss_matcher['match_score'] > 0.2]
ss_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 0            0          36     0.492826           1
# 1            1          61     0.262921           1
# 16           4           5     0.323014           1
# 17           5         107     0.508935           1
# 58          10          70     0.277948           1
# 89          12          60     0.236796           1
# 158         18          67     0.254878           1
# 167         20          59     0.235752           1
# 251         26          71     0.377686           1
# 252         27          37     0.347053           1
# 358         34           0     0.222750           1
# 452         40         111     0.265520           1
# 453         41         111     0.563316           1
#
#                                            ten_left  \
# 0                   Samsung Galaxy Z Fold3 5G 256GB
# 1                 Samsung Galaxy S22 Ultra 5G 128GB
# 16                  Samsung Galaxy Z Flip3 5G 128GB
# 17             Samsung Galaxy S21 FE 5G (6GB/128GB)
# 58                           Samsung Galaxy A52s 5G
# 89        Samsung Galaxy S20 FE 256GB (Fan Edition)
# 158                 Samsung Galaxy S21 FE 8GB 128GB
# 167                           Samsung Galaxy A22 4G
# 251          Samsung Galaxy S21 FE 5G (8GB - 256GB)
# 252                 Samsung Galaxy Z Flip3 5G 256GB
# 358               Samsung Galaxy S21 Ultra 5G 256GB
# 452  Samsung Galaxy Z Fold2 5G (Phien ban mua xuan)
# 453    Samsung Galaxy Z Fold2 5G (Phien ban mua he)
#
#                                        ten_right  gia_left  gia_right  \
# 0                Samsung Galaxy Z Fold3 5G 256GB  35990000   31990000
# 1           Samsung Galaxy S21 Ultra 5G 12/128GB  30990000   19990000
# 16               Samsung Galaxy Z Flip3 5G 128GB  21990000   17990000
# 17              Samsung Galaxy S21 FE 5G 6/128GB  15990000   15990000
# 58                        Samsung Galaxy A52s 5G   7850000    7690000
# 89                   Samsung Galaxy S20 FE 256GB  11990000   10990000
# 158             Samsung Galaxy S21 FE 5G 8/128GB  13750000   12990000
# 167                        Samsung Galaxy A32 4G   4700000    5690000
# 251             Samsung Galaxy S21 FE 5G 8/256GB  15900000   13990000
# 252              Samsung Galaxy Z Flip3 5G 256GB  22590000   19990000
# 358            Samsung Galaxy S22 Ultra 12/256GB  29800000   31990000
# 452  Samsung Galaxy Z Fold 2 5G Phien ban mua he  23000000   50000000
# 453  Samsung Galaxy Z Fold 2 5G Phien ban mua he  23000000   50000000
#
#      ram_left  ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 0          12         12              256.0               256.0
# 1           8         12              128.0               128.0
# 16          8          8              128.0               128.0
# 17          6          6              128.0               128.0
# 58          8          8              128.0               128.0
# 89          8          8              256.0               256.0
# 158         8          8              128.0               128.0
# 167         6          6              128.0               128.0
# 251         8          8              256.0               256.0
# 252         8          8              256.0               256.0
# 358        12         12              256.0               256.0
# 452        12         12              256.0               256.0
# 453        12         12              256.0               256.0
#
#      kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 0                       13.80                      13.80
# 1                        6.80                       6.80
# 16                       8.60                       6.70
# 17                       6.40                       6.40
# 58                       6.50                       6.50
# 89                       6.50                       6.50
# 158                      6.40                       6.40
# 167                      6.40                       6.40
# 251                      6.40                       6.40
# 252                      6.70                       8.60
# 358                      6.80                       6.80
# 452                     13.83                      13.82
# 453                     13.83                      13.82

# %%
values = ss_matcher['__id_right'].unique().tolist()
ss_vt_df = ss_vt_df.query("id not in @values")

ss_df = pd.concat([ss_df, ss_vt_df])
ss_df = ss_df.reset_index(drop=True)
ss_df['id'] = ss_df.index
print(len(ss_df))
# Out:
# 63

# %% [markdown]
# ## Tiki

# %%
ss_matcher = fuzzymatcher.link_table(ss_df, ss_tiki_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
ss_matcher = ss_matcher[ss_matcher['match_score'] > 0.2]
ss_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank  \
# 64            1         113     0.404282           1
# 68            3         133     0.312009           1
# 139           6         192     0.215263           1
# 140           7          52     0.211098           1
# 141           7         169     0.211098           2
# 142           8          24     0.209718           1
# 155           9         237     0.303460           1
# 156           9         242     0.297590           2
# 157          10          49     0.281326           1
# 225          12         130     0.212283           1
# 393          18          70     0.339474           1
# 394          18          89     0.339474           2
# 395          18         122     0.339474           3
# 432          22          65     0.365110           1
# 524          25         102     0.209098           1
# 525          25         144     0.209098           2
# 526          26         168     0.484899           1
# 899          34         129     0.430074           1
# 1429         46         132     0.232708           1
# 1430         47         233     0.370688           1
# 1502         50         102     0.239104           1
# 1503         50         144     0.239104           2
# 1505         52          95     0.227695           1
# 1506         52         155     0.217661           2
# 1519         56         158     0.253728           1
# 1520         56         113     0.216869           2
#
#                                        ten_left  \
# 64            Samsung Galaxy S22 Ultra 5G 128GB
# 68                  Samsung Galaxy S22 5G 128GB
# 139                      Samsung Galaxy A23 4GB
# 140                      Samsung Galaxy A13 4GB
# 141                      Samsung Galaxy A13 4GB
# 142               Samsung Galaxy A12 4GB (2021)
# 155                      Samsung Galaxy A03 3GB
# 156                      Samsung Galaxy A03 3GB
# 157                      Samsung Galaxy A52s 5G
# 225   Samsung Galaxy S20 FE 256GB (Fan Edition)
# 393             Samsung Galaxy S21 FE 8GB 128GB
# 394             Samsung Galaxy S21 FE 8GB 128GB
# 395             Samsung Galaxy S21 FE 8GB 128GB
# 432                Samsung Galaxy Note 20 Ultra
# 524                    Samsung Galaxy A73 128GB
# 525                    Samsung Galaxy A73 128GB
# 526      Samsung Galaxy S21 FE 5G (8GB - 256GB)
# 899           Samsung Galaxy S21 Ultra 5G 256GB
# 1429            Samsung Galaxy S22 Plus 8/128GB
# 1430            Samsung Galaxy A33 5G (8/128GB)
# 1502            Samsung Galaxy A73 5G (8/128GB)
# 1503            Samsung Galaxy A73 5G (8/128GB)
# 1505            Samsung Galaxy A33 5G (6/128GB)
# 1506            Samsung Galaxy A33 5G (6/128GB)
# 1519           Samsung Galaxy S22 Ultra 8/128GB
# 1520           Samsung Galaxy S22 Ultra 8/128GB
#
#                                      ten_right  gia_left  gia_right  ram_left  \
# 64       Samsung Galaxy S22 Ultra 5G 8GB/128GB  30990000   24490000         8
# 68          Samsung Galaxy S22 5G (8GB/128GB )  21990000   16390000         8
# 139             Samsung Galaxy A23 (4GB/128GB)   5690000    4829000         4
# 140             Samsung Galaxy A13 (4GB/128GB)   4690000    3770000         4
# 141             Samsung Galaxy A13 (4GB/128GB)   4690000    3899000         4
# 142              Samsung Galaxy A12 6GB (2021)   3490000    3890000         4
# 155               Samsung Galaxy A03 32GB Xanh   2990000    2990000         3
# 156                Samsung Galaxy A03 32GB Den   2990000    2990000         3
# 157         Samsung Galaxy A52s 5G (8GB/128GB)   7850000    7890000         8
# 225          Samsung Galaxy S20 FE (8GB/256GB)  11990000   11659000         8
# 393       Samsung Galaxy S21 FE 5G (8GB/128GB)  13750000   12990000         8
# 394         Samsung Galaxy S21 FE 5G 8GB/128GB  13750000   12879000         8
# 395       Samsung Galaxy S21 FE 5G (8GB/128GB)  13750000   12989000         8
# 432   Samsung Galaxy Note 20 Ultra (8GB/256GB)  19200000   20090000         8
# 524          Samsung Galaxy A73 5G (8GB/128GB)  11290000    9619000         8
# 525          Samsung Galaxy A73 5G (8GB/128GB)  11290000    9989000         8
# 526       Samsung Galaxy S21 FE 5G (8GB/256GB)  15900000   15059000         8
# 899   Samsung Galaxy S22 Ultra 5G (12GB/256GB)  29800000   25390000        12
# 1429    Samsung Galaxy S22 Plus 5G (8GB/128GB)  23990000   21699000         8
# 1430           Samsung Galaxy A33 5G (8/128GB)   7990000    8490000         8
# 1502         Samsung Galaxy A73 5G (8GB/128GB)  10990000    9619000         8
# 1503         Samsung Galaxy A73 5G (8GB/128GB)  10990000    9989000         8
# 1505         Samsung Galaxy A33 5G (6GB/128GB)   7490000    6690000         6
# 1506         Samsung Galaxy A33 5G (6GB/128GB)   7490000    6649000         6
# 1519      Samsung Galaxy S22 Ultra (8GB/128GB)  28990000   25619000         8
# 1520     Samsung Galaxy S22 Ultra 5G 8GB/128GB  28990000   24490000         8
#
#       ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 64            8              128.0               128.0
# 68            8              128.0               128.0
# 139           4              128.0               128.0
# 140           4              128.0               128.0
# 141           4              128.0               128.0
# 142           6              128.0               128.0
# 155           3               32.0                32.0
# 156           3               32.0                32.0
# 157           8              128.0               128.0
# 225           8              256.0               256.0
# 393           8              128.0               128.0
# 394           8              128.0               128.0
# 395           8              128.0               128.0
# 432           8              256.0               256.0
# 524           8              128.0               128.0
# 525           8              128.0               128.0
# 526           8              256.0               256.0
# 899          12              256.0               256.0
# 1429          8              128.0               128.0
# 1430          8              128.0               128.0
# 1502          8              128.0               128.0
# 1503          8              128.0               128.0
# 1505          6              128.0               128.0
# 1506          6              128.0               128.0
# 1519          8              128.0               128.0
# 1520          8              128.0               128.0
#
#       kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 64                         6.8                        6.8
# 68                         6.1                        6.1
# 139                        6.6                        6.6
# 140                        6.6                        6.6
# 141                        6.6                        6.6
# 142                        6.5                        6.5
# 155                        6.5                        6.5
# 156                        6.5                        6.5
# 157                        6.5                        6.5
# 225                        6.5                        6.5
# 393                        6.4                        6.4
# 394                        6.4                        6.4
# 395                        6.4                        6.4
# 432                        6.9                        6.9
# 524                        6.7                        6.7
# 525                        6.7                        6.7
# 526                        6.4                        6.4
# 899                        6.8                        6.8
# 1429                       6.6                        6.6
# 1430                       6.4                        6.4
# 1502                       6.7                        6.7
# 1503                       6.7                        6.7
# 1505                       6.4                        6.4
# 1506                       6.4                        6.4
# 1519                       6.8                        6.8
# 1520                       6.8                        6.8

# %%
values = ss_matcher['__id_right'].unique().tolist()
ss_tiki_df = ss_tiki_df.query("id not in @values")

ss_df = pd.concat([ss_df, ss_tiki_df])
ss_df = ss_df.reset_index(drop=True)
ss_df['id'] = ss_df.index
print(len(ss_df))
# Out:
# 115

# %% [markdown]
# ## Didongviet

# %%
ss_matcher = fuzzymatcher.link_table(ss_df, ss_ddv_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
ss_matcher = ss_matcher[ss_matcher['match_score'] > 0.2]
ss_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank  \
# 0             0          39     0.507607           1
# 1             1          29     0.382046           1
# 2             1         111     0.339938           2
# 8             3          25     0.302510           1
# 9             4          36     0.425334           1
# ...         ...         ...          ...         ...
# 1305        106         114     0.200807           3
# 1310        108         101     0.208096           1
# 1316        110          42     0.214906           1
# 1320        111         118     0.227115           1
# 1325        112          79     0.292693           1
#
#                                ten_left  \
# 0       Samsung Galaxy Z Fold3 5G 256GB
# 1     Samsung Galaxy S22 Ultra 5G 128GB
# 2     Samsung Galaxy S22 Ultra 5G 128GB
# 8           Samsung Galaxy S22 5G 128GB
# 9       Samsung Galaxy Z Flip3 5G 128GB
# ...                                 ...
# 1305        Samsung Galaxy S22 5G (8GB)
# 1310              Samsung A23 4GB/128GB
# 1316     Samsung Galaxy A13 (6GB/128GB)
# 1320  Samsung Galaxy A53 5G (8GB/128GB)
# 1325       Samsung Galaxy A03s 64GB Den
#
#                                             ten_right  gia_left  gia_right  \
# 0              Samsung Galaxy Z Fold3 5G (12GB|256GB)  35990000   29990000
# 1             Samsung Galaxy S22 Ultra 5G (8GB|128GB)  30990000   23390000
# 2     Samsung Galaxy S22 Ultra 5G (8GB|128GB)  (BHDT)  30990000   22790000
# 8                   Samsung Galaxy S22 5G (8GB|128GB)  21990000   14990000
# 9               Samsung Galaxy Z Flip3 5G (8GB|128GB)  21990000   16790000
# ...                                               ...       ...        ...
# 1305        Samsung Galaxy S22 5G (8GB|256GB)  (BHDT)  14660000   16690000
# 1310                   Samsung Galaxy A23 (4GB|128GB)   5050000    4790000
# 1316                   Samsung Galaxy A22 (6GB|128GB)   5190000    4390000
# 1320                   Samsung Galaxy A53 (8GB|128GB)   9690000    8090000
# 1325                   Samsung Galaxy A03s (4GB|64GB)   3690000    3390000
#
#       ram_left  ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 0           12       12.0              256.0               256.0
# 1            8        8.0              128.0               128.0
# 2            8        8.0              128.0               128.0
# 8            8        8.0              128.0               128.0
# 9            8        8.0              128.0               128.0
# ...        ...        ...                ...                 ...
# 1305         8        8.0                0.0               256.0
# 1310         4        4.0              128.0               128.0
# 1316         6        6.0              128.0               128.0
# 1320         8        8.0              128.0               128.0
# 1325         4        4.0               64.0                64.0
#
#       kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 0                         13.8                       13.8
# 1                          6.8                        6.8
# 2                          6.8                        6.8
# 8                          6.1                        6.1
# 9                          8.6                        8.6
# ...                        ...                        ...
# 1305                       6.1                        6.1
# 1310                       6.6                        6.6
# 1316                       6.6                        6.6
# 1320                       6.5                        6.5
# 1325                       6.5                        6.5
#
# [64 rows x 14 columns]

# %%
values = ss_matcher['__id_right'].unique().tolist()
ss_ddv_df = ss_ddv_df.query("id not in @values")

ss_df = pd.concat([ss_df, ss_ddv_df])
ss_df = ss_df.reset_index(drop=True)
ss_df['id'] = ss_df.index
print(len(ss_df))
# Out:
# 124

# %% [markdown]
# # Matching data Xiaomi

# %% [markdown]
# ## TGDD

# %%
xiaomi_df = xiaomi_tgdd_df
len(xiaomi_df)
# Out:
# 9

# %% [markdown]
# ## CellphoneS

# %%
xiaomi_matcher = fuzzymatcher.link_table(xiaomi_df, xiaomi_cps_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
xiaomi_matcher = xiaomi_matcher[xiaomi_matcher['match_score'] > 0.2]
xiaomi_matcher
# Out:
#     __id_left  __id_right  match_score  match_rank  \
# 36         19          41     0.201780           1
# 46         34         136     0.362153           1
#
#                       ten_left                   ten_right  gia_left  \
# 36   Xiaomi Redmi Note 10S 6GB       Xiaomi Redmi Note 10S   5990000
# 46  Xiaomi Redmi 9C (3GB/64GB)  Xiaomi Redmi 9C 3GB - 64GB   2990000
#
#     gia_right  ram_left  ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 36    4990000         6          8              128.0               128.0
# 46    2890000         3          3               64.0                64.0
#
#     kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 36                      6.43                       6.43
# 46                      6.53                       6.53

# %%
values = xiaomi_matcher['__id_right'].unique().tolist()
xiaomi_cps_df = xiaomi_cps_df.query("id not in @values")

xiaomi_df = pd.concat([xiaomi_df, xiaomi_cps_df])
xiaomi_df = xiaomi_df.reset_index(drop=True)
xiaomi_df['id'] = xiaomi_df.index
print(len(xiaomi_df))
# Out:
# 40

# %% [markdown]
# ## Viettel

# %%
xiaomi_matcher = fuzzymatcher.link_table(xiaomi_df, xiaomi_vt_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
xiaomi_matcher = xiaomi_matcher[xiaomi_matcher['match_score'] > 0.2]
xiaomi_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 0            0         103     0.225874           1
# 21           2          26     0.287782           1
# 22           2          24     0.248171           2
# 30           4          56     0.220935           1
# 49           6          51     0.386077           1
# 53           8          69     0.368467           1
# 62          11          76     0.228741           1
# 63          12          80     0.204097           1
# 66          14          41     0.366762           1
# 134         19          49     0.343708           1
# 175         22          77     0.270173           1
# 275         29          77     0.200276           1
#
#                             ten_left                         ten_right  \
# 0                          Xiaomi 12                      Xiaomi 12 5G
# 21          Xiaomi Redmi Note 11 Pro          Xiaomi Redmi Note 11 Pro
# 22          Xiaomi Redmi Note 11 Pro       Xiaomi Redmi Note 11 Pro 5G
# 30         Xiaomi Redmi Note 10S 6GB             Xiaomi Redmi Note 11S
# 49   Xiaomi Redmi Note 11 (4GB/64GB)       Xiaomi Redmi Note 11 4/64GB
# 53        Xiaomi Redmi 9C (3GB/64GB)            Xiaomi Redmi 9C 3/64GB
# 62                   Xiaomi Redmi 9A            Xiaomi Redmi 9A 2/32GB
# 63      Xiaomi Redmi 10 (4GB - 64GB)            Xiaomi Redmi 10 4/64GB
# 66        Xiaomi Redmi 10C 4GB 128GB          Xiaomi Redmi 10C 4/128GB
# 134             Xiaomi 11 Lite 5G NE      Xiaomi 11 Lite 5G NE 8/128GB
# 175     Xiaomi Redmi Note 10 Pro 8GB  Xiaomi Redmi Note 10 Pro 8/128GB
# 275     Xiaomi Redmi Note 10 Pro 6GB  Xiaomi Redmi Note 10 Pro 8/128GB
#
#      gia_left  gia_right  ram_left  ram_right  bo_nho_trong_left  \
# 0    19990000   19990000         8          8              256.0
# 21    7190000    6790000         8          8              128.0
# 22    7190000    7990000         8          8              128.0
# 30    5990000    5990000         6          8              128.0
# 49    4190000    4190000         4          4               64.0
# 53    2990000    2990000         3          3               64.0
# 62    2390000    2390000         2          2               32.0
# 63    3650000    3490000         4          4               64.0
# 66    3690000    3690000         4          4              128.0
# 134   8000000    7690000         8          8              128.0
# 175   6090000    6490000         8          8              128.0
# 275   6900000    6490000         6          8              128.0
#
#      bo_nho_trong_right  kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 0                 256.0                      6.28                       6.28
# 21                128.0                      6.67                       6.67
# 22                128.0                      6.67                       6.67
# 30                128.0                      6.43                       6.43
# 49                 64.0                      6.43                       6.43
# 53                 64.0                      6.53                       6.53
# 62                 32.0                      6.53                       6.53
# 63                 64.0                      6.50                       6.50
# 66                128.0                      6.71                       6.71
# 134               128.0                      6.55                       6.55
# 175               128.0                      6.67                       6.67
# 275               128.0                      6.67                       6.67

# %%
values = xiaomi_matcher['__id_right'].unique().tolist()
xiaomi_vt_df = xiaomi_vt_df.query("id not in @values")

xiaomi_df = pd.concat([xiaomi_df, xiaomi_vt_df])
xiaomi_df = xiaomi_df.reset_index(drop=True)
xiaomi_df['id'] = xiaomi_df.index
print(len(xiaomi_df))
# Out:
# 49

# %% [markdown]
# ## Tiki

# %%
xiaomi_matcher = fuzzymatcher.link_table(xiaomi_df, xiaomi_tiki_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
xiaomi_matcher = xiaomi_matcher[xiaomi_matcher['match_score'] > 0.2]
xiaomi_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 43           1          86     0.288593           1
# 44           1          72     0.207631           2
# 51           2          16     0.205171           1
# 52           2          17     0.205171           2
# 76           6          40     0.474416           1
# 97           8          43     0.360805           1
# 98           8         101     0.360805           2
# 99           9          71     0.259914           1
# 103         12          97     0.257414           1
# 209         16          53     0.256594           1
# 210         16          97     0.256594           2
# 297         19         105     0.444329           1
# 298         19          71     0.378828           2
# 362         22         110     0.377818           1
# 516         29         110     0.246243           1
# 692         35         105     0.284467           1
# 693         35          71     0.218966           2
# 786         39          43     0.211966           1
# 787         39         101     0.211966           2
# 893         44         226     0.308748           1
# 899         46         195     0.294451           1
# 900         47          85     0.334832           1
#
#                                  ten_left  \
# 43                    Xiaomi 11T 5G 128GB
# 44                    Xiaomi 11T 5G 128GB
# 51               Xiaomi Redmi Note 11 Pro
# 52               Xiaomi Redmi Note 11 Pro
# 76        Xiaomi Redmi Note 11 (4GB/64GB)
# 97             Xiaomi Redmi 9C (3GB/64GB)
# 98             Xiaomi Redmi 9C (3GB/64GB)
# 99                   Xiaomi Mi 11 Lite 5G
# 103          Xiaomi Redmi 10 (4GB - 64GB)
# 209         Xiaomi Redmi 10 (4GB - 128GB)
# 210         Xiaomi Redmi 10 (4GB - 128GB)
# 297                  Xiaomi 11 Lite 5G NE
# 298                  Xiaomi 11 Lite 5G NE
# 362          Xiaomi Redmi Note 10 Pro 8GB
# 516          Xiaomi Redmi Note 10 Pro 6GB
# 692  Xiaomi 11 Lite 5G NE Trang Swarovski
# 693  Xiaomi 11 Lite 5G NE Trang Swarovski
# 786  Xiaomi Redmi Note 9 3G\r\n3GB - 64GB
# 787  Xiaomi Redmi Note 9 3G\r\n3GB - 64GB
# 893          Xiaomi Redmi Note 11 4/128GB
# 899               Xiaomi Redmi 9C 4/128GB
# 900         Xiaomi Redmi Note 10S 8/128GB
#
#                                 ten_right  gia_left  gia_right  ram_left  \
# 43                 Xiaomi 11T (8GB/128GB)   8990000    8990000         8
# 44                  Xiaomi 11T (8G/128GB)   8990000    9290000         8
# 51   Xiaomi Redmi Note 11 Pro (8GB/128GB)   7190000    6699000         8
# 52   Xiaomi Redmi Note 11 Pro (8GB/128GB)   7190000    6985000         8
# 76        Xiaomi Redmi Note 11 (4GB/64GB)   4190000    4190000         4
# 97               Xiaomi Redmi 9C 3GB/64GB   2990000    2649000         3
# 98               Xiaomi Redmi 9C 3GB/64GB   2990000    2639000         3
# 99       Xiaomi 11 Lite 5G NE (8GB/128GB)   7490000    7490000         8
# 103             Xiaomi Redmi 10 4GB/128GB   3650000    3669000         4
# 209           Xiaomi Redmi 10 (4GB/128GB)   4290000    3689000         4
# 210             Xiaomi Redmi 10 4GB/128GB   4290000    3669000         4
# 297                  Xiaomi 11 Lite 5G NE   8000000    8190000         8
# 298      Xiaomi 11 Lite 5G NE (8GB/128GB)   8000000    7490000         8
# 362  Xiaomi Redmi Note 10 Pro (8GB/128GB)   6090000    7490000         8
# 516  Xiaomi Redmi Note 10 Pro (8GB/128GB)   6900000    7490000         6
# 692                  Xiaomi 11 Lite 5G NE   9490000    8190000         8
# 693      Xiaomi 11 Lite 5G NE (8GB/128GB)   9490000    7490000         8
# 786              Xiaomi Redmi 9C 3GB/64GB   3400000    2649000         3
# 787              Xiaomi Redmi 9C 3GB/64GB   3400000    2639000         3
# 893      Xiaomi Redmi Note 11 (4GB/128GB)   4490000    4490000         4
# 899           Xiaomi Redmi 9C (4GB/128GB)   3190000    3190000         4
# 900     Xiaomi Redmi Note 11S (8GB/128GB)   5690000    5690000         8
#
#      ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 43           8              128.0               128.0
# 44           8              128.0               128.0
# 51           8              128.0               128.0
# 52           8              128.0               128.0
# 76           4               64.0                64.0
# 97           3               64.0                64.0
# 98           3               64.0                64.0
# 99           8              128.0               128.0
# 103          4               64.0               128.0
# 209          4              128.0               128.0
# 210          4              128.0               128.0
# 297          8              128.0               128.0
# 298          8              128.0               128.0
# 362          8              128.0               128.0
# 516          8              128.0               128.0
# 692          8              128.0               128.0
# 693          8              128.0               128.0
# 786          3               64.0                64.0
# 787          3               64.0                64.0
# 893          4              128.0               128.0
# 899          4              128.0               128.0
# 900          8              128.0               128.0
#
#      kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 43                       6.67                       6.67
# 44                       6.67                       6.67
# 51                       6.67                       6.67
# 52                       6.67                       6.67
# 76                       6.43                       6.43
# 97                       6.53                       6.53
# 98                       6.53                       6.53
# 99                       6.55                       6.55
# 103                      6.50                       6.50
# 209                      6.50                       6.50
# 210                      6.50                       6.50
# 297                      6.55                       6.55
# 298                      6.55                       6.55
# 362                      6.67                       6.67
# 516                      6.67                       6.67
# 692                      6.55                       6.55
# 693                      6.55                       6.55
# 786                      6.53                       6.53
# 787                      6.53                       6.53
# 893                      6.43                       6.43
# 899                      6.53                       6.53
# 900                      6.43                       6.43

# %%
values = xiaomi_matcher['__id_right'].unique().tolist()
xiaomi_tiki_df = xiaomi_tiki_df.query("id not in @values")

xiaomi_df = pd.concat([xiaomi_df, xiaomi_tiki_df])
xiaomi_df = xiaomi_df.reset_index(drop=True)
xiaomi_df['id'] = xiaomi_df.index
print(len(xiaomi_df))
# Out:
# 77

# %% [markdown]
# ## Didongviet

# %%
xiaomi_matcher = fuzzymatcher.link_table(xiaomi_df, xiaomi_ddv_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
xiaomi_matcher = xiaomi_matcher[xiaomi_matcher['match_score'] > 0.2]
xiaomi_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 20           2         100     0.222252           1
# 27           6         120     0.371667           1
# 40          10          70     0.270516           1
# 85          19          51     0.349061           1
# 106         22         100     0.229647           1
# 288         47         115     0.323463           1
# 312         51         121     0.272812           1
# 313         52         121     0.272812           1
# 314         53         120     0.242118           1
# 316         54         120     0.258022           1
# 328         56         115     0.373746           1
# 332         58         121     0.282846           1
# 339         62         100     0.518332           1
# 344         65         120     0.242118           1
# 366         68         115     0.373746           1
# 367         69         100     0.518332           1
# 368         70         100     0.518332           1
# 369         71         137     0.335309           1
# 381         74         121     0.272812           1
#
#                                     ten_left  \
# 20                  Xiaomi Redmi Note 11 Pro
# 27           Xiaomi Redmi Note 11 (4GB/64GB)
# 40        Xiaomi Redmi 10 4GB - 128GB (2022)
# 85                      Xiaomi 11 Lite 5G NE
# 106             Xiaomi Redmi Note 10 Pro 8GB
# 288            Xiaomi Redmi Note 10S 8/128GB
# 312         Xiaomi Redmi Note 11 (4GB/128GB)
# 313           Xiaomi Redmi Note 11 4GB/128GB
# 314          Xiaomi Redmi Note 11 (4GB/64GB)
# 316          Xiaomi Redmi Note 11 (4GB/64GB)
# 328        Xiaomi Redmi Note 11S (8GB/128GB)
# 332         Xiaomi Redmi Note 11 (4GB/128GB)
# 339    Xiaomi Redmi Note 11 Pro 5G 8GB/128GB
# 344            Xiaomi Redmi Note 11 4GB/64GB
# 366          Xiaomi Redmi Note 11S 8GB/128GB
# 367  Xiaomi Redmi Note 11 Pro 5G (8GB/128GB)
# 368  Xiaomi Redmi Note 11 Pro 5G (8GB/128GB)
# 369               Xiaomi Redmi 9A (2GB/32GB)
# 381         Xiaomi Redmi Note 11 (4GB/128GB)
#
#                                    ten_right  gia_left  gia_right  ram_left  \
# 20   Xiaomi Redmi Note 11 Pro 5G (8GB|128GB)   7190000    7590000         8
# 27           Xiaomi Redmi Note 11 (4GB|64GB)   4190000    4190000         4
# 40          Xiaomi Redmi 10 2022 (4GB|128GB)   4290000    3690000         4
# 85          Xiaomi 11 Lite 5G NE (8GB|128GB)   8000000    7590000         8
# 106  Xiaomi Redmi Note 11 Pro 5G (8GB|128GB)   6090000    7590000         8
# 288        Xiaomi Redmi Note 11s (8GB|128GB)   5690000    5690000         8
# 312         Xiaomi Redmi Note 11 (4GB|128GB)   4179000    4360000         4
# 313         Xiaomi Redmi Note 11 (4GB|128GB)   4099000    4360000         4
# 314          Xiaomi Redmi Note 11 (4GB|64GB)   3919000    4190000         4
# 316          Xiaomi Redmi Note 11 (4GB|64GB)   3990000    4190000         4
# 328        Xiaomi Redmi Note 11s (8GB|128GB)   5829000    5690000         8
# 332         Xiaomi Redmi Note 11 (4GB|128GB)   4250000    4360000         4
# 339  Xiaomi Redmi Note 11 Pro 5G (8GB|128GB)   8009000    7590000         8
# 344          Xiaomi Redmi Note 11 (4GB|64GB)   3890000    4190000         4
# 366        Xiaomi Redmi Note 11s (8GB|128GB)   5829000    5690000         8
# 367  Xiaomi Redmi Note 11 Pro 5G (8GB|128GB)   8080000    7590000         8
# 368  Xiaomi Redmi Note 11 Pro 5G (8GB|128GB)   8059000    7590000         8
# 369               Xiaomi Redmi 9A (2GB|32GB)   2070000    2200000         2
# 381         Xiaomi Redmi Note 11 (4GB|128GB)   4279000    4360000         4
#
#      ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 20         8.0              128.0               128.0
# 27         4.0               64.0                 0.0
# 40         4.0              128.0               128.0
# 85         8.0              128.0               128.0
# 106        8.0              128.0               128.0
# 288        8.0              128.0               128.0
# 312        4.0              128.0               128.0
# 313        4.0              128.0               128.0
# 314        4.0               64.0                 0.0
# 316        4.0               64.0                 0.0
# 328        8.0              128.0               128.0
# 332        4.0              128.0               128.0
# 339        8.0              128.0               128.0
# 344        4.0               64.0                 0.0
# 366        8.0              128.0               128.0
# 367        8.0              128.0               128.0
# 368        8.0              128.0               128.0
# 369        2.0               32.0                32.0
# 381        4.0              128.0               128.0
#
#      kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 20                       6.67                       6.67
# 27                       6.43                       6.43
# 40                       6.50                       6.50
# 85                       6.55                       6.55
# 106                      6.67                       6.67
# 288                      6.43                       6.43
# 312                      6.43                       6.43
# 313                      6.43                       6.43
# 314                      6.43                       6.43
# 316                      6.43                       6.43
# 328                      6.43                       6.43
# 332                      6.43                       6.43
# 339                      6.67                       6.67
# 344                      6.43                       6.43
# 366                      6.43                       6.43
# 367                      6.67                       6.67
# 368                      6.67                       6.67
# 369                      6.53                       6.53
# 381                      6.43                       6.43

# %%
values = xiaomi_matcher['__id_right'].unique().tolist()
xiaomi_ddv_df = xiaomi_ddv_df.query("id not in @values")

xiaomi_df = pd.concat([xiaomi_df, xiaomi_ddv_df])
xiaomi_df = xiaomi_df.reset_index(drop=True)
xiaomi_df['id'] = xiaomi_df.index
print(len(xiaomi_df))
# Out:
# 80

# %% [markdown]
# ## Matching data Oppo

# %% [markdown]
# ## TGDD

# %%
oppo_df = oppo_tgdd_df
len(oppo_df)
# Out:
# 2

# %% [markdown]
# ## CellphoneS

# %%
oppo_matcher = fuzzymatcher.link_table(oppo_df, oppo_cps_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
oppo_matcher = oppo_matcher[oppo_matcher['match_score'] > 0.2]
oppo_matcher
# Out:
#    __id_left  __id_right  match_score  match_rank         ten_left  \
# 2         12           5     0.359517           1  OPPO Reno7 Z 5G
#
#            ten_right  gia_left  gia_right  ram_left  ram_right  \
# 2  OPPO Reno7 Z (5G)  10490000   10490000         8          8
#
#    bo_nho_trong_left  bo_nho_trong_right  kich_thuoc_man_hinh_left  \
# 2              128.0               128.0                      6.43
#
#    kich_thuoc_man_hinh_right
# 2                       6.43

# %%
values = oppo_matcher['__id_right'].unique().tolist()
oppo_cps_df = oppo_cps_df.query("id not in @values")

oppo_df = pd.concat([oppo_df, oppo_cps_df])
oppo_df = oppo_df.reset_index(drop=True)
oppo_df['id'] = oppo_df.index
print(len(oppo_df))
# Out:
# 21

# %% [markdown]
# ## Viettel

# %%
oppo_matcher = fuzzymatcher.link_table(oppo_df, oppo_vt_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
oppo_matcher = oppo_matcher[oppo_matcher['match_score'] > 0.2]
oppo_matcher
# Out:
#    __id_left  __id_right  match_score  match_rank         ten_left  \
# 1          1          30     0.231904           1  OPPO Reno7 Z 5G
#
#          ten_right  gia_left  gia_right  ram_left  ram_right  \
# 1  OPPO Reno7 Z 5G  10490000    9990000         8          8
#
#    bo_nho_trong_left  bo_nho_trong_right  kich_thuoc_man_hinh_left  \
# 1              128.0               128.0                      6.43
#
#    kich_thuoc_man_hinh_right
# 1                       6.43

# %%
values = oppo_matcher['__id_right'].unique().tolist()
oppo_vt_df = oppo_vt_df.query("id not in @values")

oppo_df = pd.concat([oppo_df, oppo_vt_df])
oppo_df = oppo_df.reset_index(drop=True)
oppo_df['id'] = oppo_df.index
print(len(oppo_df))
# Out:
# 30

# %% [markdown]
# ## Tiki

# %%
oppo_matcher = fuzzymatcher.link_table(oppo_df, oppo_tiki_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
oppo_matcher = oppo_matcher[oppo_matcher['match_score'] > 0.2]
oppo_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank         ten_left  \
# 1            1         172     0.229514           1  OPPO Reno7 Z 5G
# 2            2         225     0.229514           1  OPPO Reno6 Z 5G
# 262         20          41     0.201006           1        OPPO A15s
# 277         23         234     0.200681           1         OPPO A76
#
#                        ten_right  gia_left  gia_right  ram_left  ram_right  \
# 1    OPPO RENO7 Z 5G (8GB/128GB)  10490000    9990000         8          8
# 2    Oppo Reno6 Z 5G (8GB/128GB)   7390000    8289000         8          8
# 262          Oppo A15s (4GB/64G)   3790000    3790000         4          4
# 277           Oppo A76 6GB/128GB   5990000    5990000         6          6
#
#      bo_nho_trong_left  bo_nho_trong_right  kich_thuoc_man_hinh_left  \
# 1                128.0               128.0                      6.43
# 2                128.0               128.0                      6.43
# 262               64.0                64.0                      6.52
# 277              128.0               128.0                      6.56
#
#      kich_thuoc_man_hinh_right
# 1                         6.43
# 2                         6.43
# 262                       6.52
# 277                       6.56

# %%
values = oppo_matcher['__id_right'].unique().tolist()
oppo_tiki_df = oppo_tiki_df.query("id not in @values")

oppo_df = pd.concat([oppo_df, oppo_tiki_df])
oppo_df = oppo_df.reset_index(drop=True)
oppo_df['id'] = oppo_df.index
print(len(oppo_df))
# Out:
# 60

# %% [markdown]
# ## Didongviet

# %%
oppo_matcher = fuzzymatcher.link_table(oppo_df, oppo_ddv_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
oppo_matcher = oppo_matcher[oppo_matcher['match_score'] > 0.2]
oppo_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank  \
# 11           5          49     0.216617           1
# 192         32          48     0.235673           1
# 218         39          43     0.329066           1
# 219         40         131     0.204232           1
# 233         42          40     0.360875           1
# 237         45          40     0.344971           1
# 238         46         116     0.270794           1
# 249         49          40     0.344971           1
# 262         51          43     0.424311           1
# 263         52          50     0.313863           1
# 264         53          43     0.344971           1
# 265         54          43     0.344971           1
# 278         56          40     0.355005           1
#
#                       ten_left                    ten_right  gia_left  \
# 11               OPPO Reno6 5G    OPPO Reno6 5G (8GB|128GB)  10290000
# 192    Oppo Reno 5G (8GB/128G)  OPPO Reno6 Z 5G (8GB|128GB)   7290000
# 218          Oppo A55 4GB/64GB          OPPO A55 (4GB|64GB)   4069000
# 219  OPPO RENO7 4G (8GB/128GB)    OPPO Reno7 4G (8GB|128GB)   8490000
# 233         Oppo A16k 3GB/32GB         OPPO A16K (3GB|32GB)   3290000
# 237       OPPO A16K (3GB/32GB)         OPPO A16K (3GB|32GB)   2969000
# 238       OPPO A76 (6GB/128GB)         OPPO A76 (6GB|128GB)   5385000
# 249       Oppo A16K (3GB/32GB)         OPPO A16K (3GB|32GB)   3049000
# 262        Oppo A55 (4GB/64GB)          OPPO A55 (4GB|64GB)   3970000
# 263       OPPO A95 (8GB/128GB)         OPPO A95 (8GB/128GB)   5990000
# 264        Oppo A55 (4GB/64GB)          OPPO A55 (4GB|64GB)   4490000
# 265        OPPO A55 (4GB/64GB)          OPPO A55 (4GB|64GB)   4490000
# 278       OPPO A16K (3GB/32GB)         OPPO A16K (3GB|32GB)   3190000
#
#      gia_right  ram_left  ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 11    10290000         8        8.0              128.0               128.0
# 192    7290000         8        8.0              128.0               128.0
# 218    3990000         4        4.0               64.0                64.0
# 219    7790000         8        8.0              256.0                 0.0
# 233    2890000         3        3.0               32.0                32.0
# 237    2890000         3        3.0               32.0                32.0
# 238    5090000         6        6.0              128.0               128.0
# 249    2890000         3        3.0               32.0                32.0
# 262    3990000         4        4.0               64.0                64.0
# 263    5990000         8        8.0              128.0               128.0
# 264    3990000         4        4.0               64.0                64.0
# 265    3990000         4        4.0               64.0                64.0
# 278    2890000         3        3.0               32.0                32.0
#
#      kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 11                       6.43                       6.43
# 192                      6.43                       6.43
# 218                      6.50                       6.50
# 219                      6.40                       6.40
# 233                      6.52                       6.52
# 237                      6.52                       6.52
# 238                      6.56                       6.56
# 249                      6.52                       6.52
# 262                      6.50                       6.50
# 263                      6.43                       6.43
# 264                      6.50                       6.50
# 265                      6.50                       6.50
# 278                      6.52                       6.52

# %%
values = oppo_matcher['__id_right'].unique().tolist()
oppo_ddv_df = oppo_ddv_df.query("id not in @values")

oppo_df = pd.concat([oppo_df, oppo_ddv_df])
oppo_df = oppo_df.reset_index(drop=True)
oppo_df['id'] = oppo_df.index
print(len(oppo_df))
# Out:
# 65

# %% [markdown]
# # Matching data other

# %% [markdown]
# ## TGDD

# %%
other_df = other_tgdd_df
len(other_df)
# Out:
# 11

# %% [markdown]
# ## CellphoneS

# %%
other_matcher = fuzzymatcher.link_table(other_df, other_cps_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
other_matcher = other_matcher[other_matcher['match_score'] > 0.2]
other_matcher
# Out:
#      __id_left  __id_right  match_score  match_rank              ten_left  \
# 0           14         159     0.209219           1             Vivo V23e
# 1           14          99     0.209040           2             Vivo V23e
# 16          22         188     0.244783           1      Realme C25Y 64GB
# 19          24          79     0.238506           1       Realme C35 64GB
# 23          26          96     0.250647           1              Vivo Y21
# 110         28          77     0.255911           1             Vivo Y15s
# 114         32          55     0.289655           1     Realme C11 (2021)
# 115         35         109     0.246657           1  Nokia 105 Single SIM
#
#                  ten_right  gia_left  gia_right  ram_left  ram_right  \
# 0              Vivo V21 5G   8490000    8500000         8          8
# 1                Vivo V23e   8490000    7490000         8          8
# 16    Realme C25Y 4GB 64GB   4690000    3790000         4          4
# 19     Realme C35 4GB 64GB   4290000    3990000         4          4
# 23                Vivo Y21   3990000    3600000         4          4
# 110              Vivo Y15s   3490000    2850000         3          3
# 114      Realme C11 (2021)   2990000    2490000         2          2
# 115  Nokia 105 (2019) 1 SM    480000     480000         0          0
#
#      bo_nho_trong_left  bo_nho_trong_right  kich_thuoc_man_hinh_left  \
# 0                128.0               128.0                      6.44
# 1                128.0               128.0                      6.44
# 16                64.0                64.0                      6.50
# 19                64.0                64.0                      6.60
# 23                64.0                64.0                      6.51
# 110               32.0                32.0                      6.51
# 114               32.0                32.0                      6.50
# 115                0.0                 0.0                      1.77
#
#      kich_thuoc_man_hinh_right
# 0                         6.44
# 1                         6.44
# 16                        6.50
# 19                        6.60
# 23                        6.51
# 110                       6.51
# 114                       6.50
# 115                       1.77

# %%
values = other_matcher['__id_right'].unique().tolist()
other_cps_df = other_cps_df.query("id not in @values")

other_df = pd.concat([other_df, other_cps_df])
other_df = other_df.reset_index(drop=True)
other_df['id'] = other_df.index
print(len(other_df))
# Out:
# 111

# %% [markdown]
# ## Viettel

# %%
other_matcher = fuzzymatcher.link_table(other_df, other_vt_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
other_matcher = other_matcher[other_matcher['match_score'] > 0.2]
other_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank  \
# 0             0         100     0.248892           1
# 44            4          91     0.281286           1
# 45            5          78     0.247252           1
# 86            7          31     0.229220           1
# 770          28         106     0.331991           1
# 1012         36          27     0.307466           1
# 1014         38         113     0.284740           1
# 1203         44          32     0.228824           1
# 1253         47          43     0.349899           1
# 1374         51         114     0.274706           1
# 1460         57         101     0.219140           1
# 1705         67          90     0.307058           1
# 1706         68          68     0.227531           1
# 2136         82          82     0.387415           1
# 2708        100          44     0.390036           1
#
#                       ten_left                     ten_right  gia_left  \
# 0                    Vivo V23e                     Vivo V23e   8490000
# 44             Realme C35 64GB           Realme C35 (4/64GB)   4290000
# 45                    Vivo Y21                      Vivo Y21   3990000
# 86                   Vivo Y15s                     Vivo Y15s   3490000
# 770                Vivo V23 5G                   Vivo V23 5G  10990000
# 1012   Nokia C21 Plus 3GB 64GB       Nokia C21 Plus 3GB-64GB   2990000
# 1014              Nokia 110 4G                  Nokia 110 4G    850000
# 1203                 Vivo Y33S                     Vivo Y33s   5900000
# 1253   Vivo Y21S (4GB - 128GB)           Vivo Y21s 4GB/128GB   4300000
# 1374              Nokia 105 4G                  Nokia 105 4G    750000
# 1460                 Nokia C30                     Nokia C30   2590000
# 1705   Nokia C21 Plus 3GB 32GB       Nokia C21 Plus 3GB-32GB   2790000
# 1706              Nokia 215 4G                  Nokia 215 4G    829000
# 2136  Realme C11 2021 4GB 64GB  Realme C11 2021 (4GB - 64GB)   3190000
# 2708   Vivo Y21S (6GB - 128GB)           Vivo Y21s 6GB/128GB   4650000
#
#       gia_right  ram_left  ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 0       6990000         8          8            128.000          128.000000
# 44      4290000         4          4             64.000           64.000000
# 45      3790000         4          4             64.000           64.000000
# 86      3090000         3          3             32.000           32.000000
# 770    12490000         8          8            128.000          128.000000
# 1012    2890000         3          3             64.000           64.000000
# 1014     850000         0          0              0.125            0.046875
# 1203    5340000         8          8            128.000          128.000000
# 1253    4690000         4          4            128.000          128.000000
# 1374     750000         0          0              0.125            0.046875
# 1460    2950000         3          3             32.000           32.000000
# 1705    2690000         3          3             32.000           32.000000
# 1706     900000         0          0              0.125            0.125000
# 2136    3490000         4          4             64.000           64.000000
# 2708    5190000         6          6            128.000          128.000000
#
#       kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 0                         6.44                       6.44
# 44                        6.60                       6.58
# 45                        6.51                       6.51
# 86                        6.51                       6.51
# 770                       6.44                       6.44
# 1012                      6.52                       6.50
# 1014                      1.80                       1.80
# 1203                      6.58                       6.58
# 1253                      6.51                       6.51
# 1374                      1.80                       1.80
# 1460                      6.82                       6.82
# 1705                      6.52                       6.50
# 1706                      2.40                       2.40
# 2136                      6.50                       6.50
# 2708                      6.51                       6.51

# %%
values = other_matcher['__id_right'].unique().tolist()
other_vt_df = other_vt_df.query("id not in @values")

other_df = pd.concat([other_df, other_vt_df])
other_df = other_df.reset_index(drop=True)
other_df['id'] = other_df.index
print(len(other_df))
# Out:
# 136

# %% [markdown]
# ## Tiki

# %%
other_matcher = fuzzymatcher.link_table(other_df, other_tiki_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
other_matcher = other_matcher[other_matcher['match_score'] > 0.2]
other_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank  \
# 77            4         236     0.234695           1
# 84            8         126     0.250279           1
# 480          16           4     0.299074           1
# 482          17         134     0.480977           1
# 989          28         112     0.466208           1
# 1127         32         121     0.300199           1
# 1381         36          68     0.457669           1
# 1382         36         183     0.403774           2
# 1662         41         106     0.238316           1
# 1663         41         213     0.238316           2
# 1746         43          47     0.469610           1
# 1747         43         164     0.469610           2
# 2257         52         181     0.258316           1
# 2678         62         199     0.266862           1
# 2822         67          63     0.455145           1
# 3109         72         201     0.205874           1
# 3593         82         108     0.333990           1
# 3725         86         171     0.281169           1
# 3858         89         121     0.252332           1
# 4490         98         121     0.210171           1
# 4560         99         216     0.329973           1
# 4633        102          47     0.214380           1
# 5116        113         213     0.377987           1
# 5117        113         106     0.248355           2
# 5404        121         205     0.363040           1
# 5405        121         159     0.353006           2
# 5406        121         185     0.353006           3
# 5407        121          60     0.232865           4
# 5414        122         199     0.375213           1
# 6065        135         140     0.339790           1
#
#                                       ten_left  \
# 77                             Realme C35 64GB
# 84                             Realme C21Y 3GB
# 480                             Tecno Spark 8C
# 482   Nubia Red Magic 6s Pro Cyborg 12GB 128GB
# 989                                Vivo V23 5G
# 1127                              Vsmart Joy 4
# 1381                   Nokia C21 Plus 3GB 64GB
# 1382                   Nokia C21 Plus 3GB 64GB
# 1662                        Nokia C20 2GB 16GB
# 1663                        Nokia C20 2GB 16GB
# 1746                   Tecno Spark 7T 4GB 64GB
# 1747                   Tecno Spark 7T 4GB 64GB
# 2257                                 Nokia G10
# 2678                               Realme 8 5G
# 2822                   Nokia C21 Plus 3GB 32GB
# 3109                              Realme 8 Pro
# 3593                  Realme C11 2021 4GB 64GB
# 3725                      Realme C21Y 4GB 64GB
# 3858                          Vsmart Joy 4 4GB
# 4490                          Vsmart Joy 4 6GB
# 4560                   Nokia C21 Plus 2GB 64GB
# 4633                  Tecno Spark 7T 6GB 128GB
# 5116                        Nokia C20 2GB-16GB
# 5117                        Nokia C20 2GB-16GB
# 5404              Realme C11 2021 (2GB - 32GB)
# 5405              Realme C11 2021 (2GB - 32GB)
# 5406              Realme C11 2021 (2GB - 32GB)
# 5407              Realme C11 2021 (2GB - 32GB)
# 5414                               Realme 8 5G
# 6065               ZTE Blade A31 Plus (2/32GB)
#
#                                           ten_right  gia_left  gia_right  \
# 77                              Realme C35 4GB/64GB   4290000    3899000
# 84                             Realme C21Y 3GB/32GB   3390000    2559000
# 480                       TECNO Spark 8C (4GB/64GB)   2650000    2648000
# 482   ZTE Nubia RedMagic 6s Pro Cyborg 12GB l 128GB  16490000   16290000
# 989                         Vivo V23 5G (8GB/128GB)  10990000   10990000
# 1127                                   Vsmart Joy 4   3290000    3190000
# 1381                      Nokia C21 Plus (3GB/64GB)   2990000    2790000
# 1382                      Nokia C21 Plus (2GB/64GB)   2990000    2450000
# 1662                           Nokia C20 (2GB/16GB)   1790000    1680000
# 1663                           Nokia C20 (2GB/16GB)   1790000    1989000
# 1746                        Tecno Spark 7T 4GB/64GB   2750000    2789000
# 1747                      TECNO Spark 7T (4GB/64GB)   2750000    2929000
# 2257                           Nokia G10 (4GB/64GB)   2990000    2990000
# 2678                                    Realme 8 5G   6790000    7490000
# 2822                      Nokia C21 Plus (3GB/32GB)   2790000    2590000
# 3109                       Realme 8 Pro (8GB/128GB)   7590000    7990000
# 3593                     Realme C11 2021 (4GB/64GB)   3190000    3479000
# 3725                           Realme C21Y 4GB/64GB   3390000    3090000
# 3858                                   Vsmart Joy 4   3590000    3190000
# 4490                                   Vsmart Joy 4   3990000    3190000
# 4560                        Nokia C21 Plus 2GB/64GB   2690000    2450000
# 4633                        Tecno Spark 7T 4GB/64GB   3490000    2789000
# 5116                           Nokia C20 (2GB/16GB)   1990000    1989000
# 5117                           Nokia C20 (2GB/16GB)   1990000    1680000
# 5404                     Realme C11 2021 (2GB/32GB)   2590000    2439000
# 5405                     Realme C11 2021 (2GB/32GB)   2590000    2350000
# 5406                    Realme C11 (2021)(2GB/32GB)   2590000    2690000
# 5407                          Realme C11 (2GB/32GB)   2590000    2439000
# 5414                                    Realme 8 5G   7490000    7490000
# 6065                  ZTE Blade A31 Plus 2GB l 32GB   1990000    1890000
#
#       ram_left  ram_right  bo_nho_trong_left  bo_nho_trong_right  \
# 77           4          4               64.0                64.0
# 84           3          3               32.0                32.0
# 480          0          4               64.0                64.0
# 482         12         12              128.0               128.0
# 989          8          8              128.0               128.0
# 1127         3          0               64.0                64.0
# 1381         3          3               64.0                64.0
# 1382         3          3               64.0                64.0
# 1662         2          2               16.0                16.0
# 1663         2          2               16.0                16.0
# 1746         4          4               64.0                64.0
# 1747         4          4               64.0                64.0
# 2257         4          4               64.0                64.0
# 2678         8          8              128.0               128.0
# 2822         3          3               32.0                32.0
# 3109         8          8              128.0               128.0
# 3593         4          4               64.0                64.0
# 3725         4          4               64.0                64.0
# 3858         4          0               64.0                64.0
# 4490         6          0               64.0                64.0
# 4560         2          2               64.0                64.0
# 4633         6          4              128.0                64.0
# 5116         0          2               16.0                16.0
# 5117         0          2               16.0                16.0
# 5404         2          2               32.0                32.0
# 5405         2          2               32.0                32.0
# 5406         2          2               32.0                32.0
# 5407         2          2               32.0                32.0
# 5414         0          8              128.0               128.0
# 6065         2          0               32.0                 0.0
#
#       kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 77                        6.60                       6.60
# 84                        6.50                       6.50
# 480                       6.60                       6.60
# 482                       6.80                       6.80
# 989                       6.44                       6.44
# 1127                      6.50                       6.53
# 1381                      6.52                       6.52
# 1382                      6.52                       6.52
# 1662                      6.52                       6.50
# 1663                      6.52                       6.50
# 1746                      6.52                       6.52
# 1747                      6.52                       6.52
# 2257                      6.50                       6.50
# 2678                      6.50                       6.50
# 2822                      6.52                       6.52
# 3109                      6.40                       6.40
# 3593                      6.50                       6.50
# 3725                      6.50                       6.50
# 3858                      6.50                       6.53
# 4490                      6.50                       6.53
# 4560                      6.52                       6.50
# 4633                      6.52                       6.52
# 5116                      6.50                       6.50
# 5117                      6.50                       6.50
# 5404                      6.50                       6.50
# 5405                      6.50                       6.50
# 5406                      6.50                       6.50
# 5407                      6.50                       6.50
# 5414                      6.50                       6.50
# 6065                      6.00                       6.00

# %%
values = other_matcher['__id_right'].unique().tolist()
other_tiki_df = other_tiki_df.query("id not in @values")

other_df = pd.concat([other_df, other_tiki_df])
other_df = other_df.reset_index(drop=True)
other_df['id'] = other_df.index
print(len(other_df))
# Out:
# 200

# %% [markdown]
# ## Didongviet

# %%
other_matcher = fuzzymatcher.link_table(other_df, other_ddv_df, left_on, right_on, left_id_col = "id", right_id_col = "id")
other_matcher = other_matcher[other_matcher['match_score'] > 0.2]
other_matcher
# Out:
#       __id_left  __id_right  match_score  match_rank  \
# 960          24          69     0.330364           1
# 1846         46          68     0.303872           1
# 1883         47          59     0.537361           1
# 2022         51          67     0.299264           1
# 4061        100          58     0.601440           1
# 5667        139          69     0.207346           1
# 6250        155          61     0.202182           1
# 6483        162          60     0.291509           1
# 6577        165          61     0.227908           1
# 6762        170          69     0.466554           1
# 6855        173          60     0.212412           1
# 6949        176          55     0.214795           1
# 7181        183          68     0.286843           1
# 7228        185          60     0.212412           1
# 7371        191          68     0.270939           1
# 7419        194          60     0.307413           1
# 7421        195          60     0.233687           1
# 7423        196          55     0.684595           1
# 7424        197          61     0.307005           1
#
#                                    ten_left                  ten_right  \
# 960                               Nokia G21      Nokia G21 (4GB|128GB)
# 1846                     Nokia C30 2GB 32GB       Nokia C30 (3GB|32GB)
# 1883                Vivo Y21S (4GB - 128GB)      Vivo Y21s (4GB|128GB)
# 2022                           Nokia 105 4G               Nokia 105 4G
# 4061                Vivo Y21S (6GB - 128GB)      Vivo Y21s (6GB|128GB)
# 5667                     Nokia G10 4GB/64GB      Nokia G21 (4GB|128GB)
# 6250  Vivo Y15s (3GB/32GB)  Hang Chinh Hang       Vivo Y15s (3GB|32GB)
# 6483                      Vivo Y21 4GB/64GB        Vivo Y21 (4GB|64GB)
# 6577                     Vivo Y12s 3GB/32GB       Vivo Y15s (3GB|32GB)
# 6762                    Nokia G21 4GB/128GB      Nokia G21 (4GB|128GB)
# 6855                      Vivo Y20 4GB/64GB        Vivo Y21 (4GB|64GB)
# 6949                Nokia C21 Plus 2GB/32GB  Nokia C01 Plus (2GB|16GB)
# 7181                     Nokia C30 3GB/32GB       Nokia C30 (3GB|32GB)
# 7228                   Vivo Y15a (4GB/64GB)        Vivo Y21 (4GB|64GB)
# 7371                   Nokia C30 (3GB/32GB)       Nokia C30 (3GB|32GB)
# 7419                    Vivo Y21 (4GB/64GB)        Vivo Y21 (4GB|64GB)
# 7421                     Vivo Y15A 4GB/64GB        Vivo Y21 (4GB|64GB)
# 7423                Nokia C01 Plus 2GB/16GB  Nokia C01 Plus (2GB|16GB)
# 7424                     Vivo Y15s 3GB/32GB       Vivo Y15s (3GB|32GB)
#
#       gia_left  gia_right  ram_left  ram_right  bo_nho_trong_left  \
# 960    3990000    3990000         4   4.000000            128.000
# 1846   2390000    3590000         2   3.000000             32.000
# 1883   4300000    4290000         4   4.000000            128.000
# 2022    750000     670000         0   0.046875              0.125
# 4061   4650000    4650000         6   6.000000            128.000
# 5667   2890000    3990000         4   4.000000             64.000
# 6250   2790000    2750000         3   3.000000             32.000
# 6483   3679000    3490000         4   4.000000             64.000
# 6577   3169000    2750000         3   3.000000             32.000
# 6762   3690000    3990000         4   4.000000            128.000
# 6855   3599000    3490000         4   4.000000             64.000
# 6949   2389000    1420000         2   2.000000             32.000
# 7181   2890000    3590000         3   3.000000             32.000
# 7228   2970000    3490000         4   4.000000             64.000
# 7371   2959000    3590000         3   3.000000             32.000
# 7419   3390000    3490000         4   4.000000             64.000
# 7421   2990000    3490000         4   4.000000             64.000
# 7423   1599000    1420000         2   2.000000             16.000
# 7424   2819000    2750000         3   3.000000             32.000
#
#       bo_nho_trong_right  kich_thuoc_man_hinh_left  kich_thuoc_man_hinh_right
# 960              128.000                      6.50                       6.50
# 1846              32.000                      6.82                       6.82
# 1883             128.000                      6.51                       6.51
# 2022               0.125                      1.80                       1.80
# 4061             128.000                      6.51                       6.51
# 5667             128.000                      6.50                       6.50
# 6250              32.000                      6.50                       6.51
# 6483              64.000                      6.50                       6.51
# 6577              32.000                      6.50                       6.51
# 6762             128.000                      6.50                       6.50
# 6855              64.000                      6.50                       6.51
# 6949              16.000                      6.50                       5.45
# 7181              32.000                      6.81                       6.82
# 7228              64.000                      6.50                       6.51
# 7371              32.000                      6.81                       6.82
# 7419              64.000                      6.50                       6.51
# 7421              64.000                      6.50                       6.51
# 7423              16.000                      5.45                       5.45
# 7424              32.000                      6.50                       6.51

# %%
values = other_matcher['__id_right'].unique().tolist()
other_ddv_df = other_ddv_df.query("id not in @values")

other_df = pd.concat([other_df, other_ddv_df])
other_df = other_df.reset_index(drop=True)
other_df['id'] = other_df.index
print(len(other_df))
# Out:
# 238

# %% [markdown]
# ## Merge all

# %%
df = pd.concat([apple_df, ss_df, xiaomi_df, oppo_df, other_df])
df = df.reset_index(drop=True)
print(len(df))
# Out:
# 584

# %%
df = df.drop_duplicates(subset=['ten'])
print(len(df))
# Out:
# 511

# %%
df.head()
# Out:
#                                ten       gia cong_nghe_man_hinh  \
# 0              iPhone 12 Pro 256GB  26290000               OLED
# 1                   iPhone 12 64GB  19990000               OLED
# 2              iPhone 12 mini 64GB  18990000               OLED
# 3  iPhone SE 64GB (2020) (Hộp mới)   9490000            IPS LCD
# 4                   iPhone 11 64GB  11690000            IPS LCD
#
#                        cpu  ram  bo_nho_trong                  sim       pin  \
# 0  Apple A14 Bionic 6 nhân  6.0         256.0  1 Nano SIM & 1 eSIM  2815 mAh
# 1  Apple A14 Bionic 6 nhân  4.0          64.0  1 Nano SIM & 1 eSIM  2815 mAh
# 2  Apple A14 Bionic 6 nhân  4.0          64.0  1 Nano SIM & 1 eSIM  2227 mAh
# 3  Apple A13 Bionic 6 nhân  3.0          64.0  1 Nano SIM & 1 eSIM  1821 mAh
# 4               A13 Bionic  4.0          64.0      Nano-SIM + eSIM  3110 mAh
#
#    kich_thuoc_man_hinh  id               src thuong_hieu
# 0                  6.1   0  Thế giới di động       apple
# 1                  6.1   1  Thế giới di động       apple
# 2                  5.4   2  Thế giới di động       apple
# 3                  4.7   3  Thế giới di động       apple
# 4                  6.1   4        CellphoneS       apple

# %%
df.to_csv('clean_data/final_data.csv', index=False)
df.to_json('clean_data/final_data.json', orient="records")
